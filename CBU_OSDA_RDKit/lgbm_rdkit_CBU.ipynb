# %% [markdown]
# # mor

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 84].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951     True
# 29952     True
# 29977     True
# 29978     True
# Name: mor, Length: 4697, dtype: object
# mor
# False    2755
# True     1942
# Name: count, dtype: int64
#                     importance
# Al / Si            2636.546042
# Na / Si            1232.134674
# F / Si                7.345793
# H2O / Si           1305.030712
# sda1 / Si          1093.931210
# ...                        ...
# fr_Ndealkylation2    21.448601
# fr_bicyclic           2.275880
# fr_piperdine         58.174963
# fr_quatN              0.000000
# fr_unbrch_alkane     16.762120
#
# [76 rows x 1 columns]
#        False  True
# False   2048    18
# True      35  1421
#        False  True
# False    645    44
# True      52   434
# 正解率(Accuracy) : 訓練 0.9849517319704714, 検証 0.9182978723404255
# 適合率(Precision) : 訓練 0.9874913134120917, 検証 0.9079497907949791
# 再現率(Recall) : 訓練 0.9759615384615384, 検証 0.8930041152263375
# F1スコア : 訓練 0.981692573402418, 検証 0.9004149377593361
#  93%|=================== | 3274/3522 [00:12<00:00]

# %% [markdown]
# # bea

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 85].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951    False
# 29952    False
# 29977     True
# 29978     True
# Name: bea, Length: 4697, dtype: object
# bea
# False    4233
# True      464
# Name: count, dtype: int64
#                    importance
# Al / Si            749.249875
# Na / Si            574.355903
# F / Si              26.083841
# H2O / Si           942.595264
# sda1 / Si          904.183167
# ...                       ...
# fr_Ndealkylation2    3.065630
# fr_bicyclic          3.301178
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.614897
#
# [76 rows x 1 columns]
#        False  True
# False   3172     2
# True       2   346
#        False  True
# False   1041    18
# True      17    99
# 正解率(Accuracy) : 訓練 0.9988642816581488, 検証 0.9702127659574468
# 適合率(Precision) : 訓練 0.9942528735632183, 検証 0.8461538461538461
# 再現率(Recall) : 訓練 0.9942528735632183, 検証 0.853448275862069
# F1スコア : 訓練 0.9942528735632183, 検証 0.8497854077253219
#  93%|=================== | 3265/3522 [00:12<00:00]

# %% [markdown]
# # mtt

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 86].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: mtt, Length: 4697, dtype: object
# mtt
# False    4192
# True      505
# Name: count, dtype: int64
#                     importance
# Al / Si            1026.214102
# Na / Si             845.585756
# F / Si               29.648338
# H2O / Si           1163.554983
# sda1 / Si           553.274935
# ...                        ...
# fr_Ndealkylation2     0.000000
# fr_bicyclic           0.000000
# fr_piperdine          0.000000
# fr_quatN              0.000000
# fr_unbrch_alkane     15.849939
#
# [76 rows x 1 columns]
#        False  True
# False   3142     1
# True       5   374
#        False  True
# False   1031    18
# True      22   104
# 正解率(Accuracy) : 訓練 0.9982964224872232, 検証 0.9659574468085106
# 適合率(Precision) : 訓練 0.9973333333333333, 検証 0.8524590163934426
# 再現率(Recall) : 訓練 0.9868073878627969, 検証 0.8253968253968254
# F1スコア : 訓練 0.9920424403183024, 検証 0.8387096774193549
#  93%|=================== | 3263/3522 [00:11<00:00]

# %% [markdown]
# # cas

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 87].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951     True
# 29952     True
# 29977    False
# 29978    False
# Name: cas, Length: 4697, dtype: object
# cas
# False    3357
# True     1340
# Name: count, dtype: int64
#                     importance
# Al / Si            3893.181136
# Na / Si            1349.400771
# F / Si               99.963411
# H2O / Si            744.790532
# sda1 / Si           524.421389
# ...                        ...
# fr_Ndealkylation2    19.901760
# fr_bicyclic           5.988589
# fr_piperdine         23.377096
# fr_quatN              0.000000
# fr_unbrch_alkane     46.860289
#
# [76 rows x 1 columns]
#        False  True
# False   2505    12
# True      14   991
#        False  True
# False    812    28
# True      42   293
# 正解率(Accuracy) : 訓練 0.9926178307779671, 検証 0.9404255319148936
# 適合率(Precision) : 訓練 0.9880358923230309, 検証 0.9127725856697819
# 再現率(Recall) : 訓練 0.9860696517412936, 検証 0.8746268656716418
# F1スコア : 訓練 0.9870517928286853, 検証 0.8932926829268293
#  96%|=================== | 3371/3522 [00:12<00:00]

# %% [markdown]
# # d6r

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 88].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251       True
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: d6r, Length: 4697, dtype: object
# d6r
# False    3705
# True      992
# Name: count, dtype: int64
#                     importance
# Al / Si            1916.246925
# Na / Si            1117.935031
# F / Si               65.346794
# H2O / Si           1152.029959
# sda1 / Si          1229.966083
# ...                        ...
# fr_Ndealkylation2    10.170035
# fr_bicyclic           0.000000
# fr_piperdine          0.000000
# fr_quatN              0.000000
# fr_unbrch_alkane     31.405538
#
# [76 rows x 1 columns]
#        False  True
# False   2775     3
# True      10   734
#        False  True
# False    897    30
# True      39   209
# 正解率(Accuracy) : 訓練 0.9963089153889836, 検証 0.9412765957446808
# 適合率(Precision) : 訓練 0.9959294436906377, 検証 0.8744769874476988
# 再現率(Recall) : 訓練 0.9865591397849462, 検証 0.842741935483871
# F1スコア : 訓練 0.9912221471978393, 検証 0.8583162217659137
#  99%|===================| 3482/3522 [00:13<00:00]

# %% [markdown]
# # fer

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 89].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: fer, Length: 4697, dtype: object
# fer
# False    4455
# True      242
# Name: count, dtype: int64
#                     importance
# Al / Si            1314.008201
# Na / Si             788.371266
# F / Si               50.722746
# H2O / Si            570.594284
# sda1 / Si           466.278056
# ...                        ...
# fr_Ndealkylation2     0.084425
# fr_bicyclic           0.000000
# fr_piperdine          0.000000
# fr_quatN              0.000000
# fr_unbrch_alkane      4.738961
#
# [76 rows x 1 columns]
#        False  True
# False   3334     7
# True       4   177
#        False  True
# False   1108     6
# True      17    44
# 正解率(Accuracy) : 訓練 0.9968767745599092, 検証 0.9804255319148936
# 適合率(Precision) : 訓練 0.9619565217391305, 検証 0.88
# 再現率(Recall) : 訓練 0.9779005524861878, 検証 0.7213114754098361
# F1スコア : 訓練 0.9698630136986301, 検証 0.7927927927927928
#  96%|=================== | 3395/3522 [00:13<00:00]

# %% [markdown]
# # mel

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 90].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951     True
# 29952     True
# 29977    False
# 29978    False
# Name: mel, Length: 4697, dtype: object
# mel
# False    3364
# True     1333
# Name: count, dtype: int64
#                     importance
# Al / Si            2477.782019
# Na / Si            1027.190421
# F / Si               77.023681
# H2O / Si            694.849314
# sda1 / Si           798.066311
# ...                        ...
# fr_Ndealkylation2    16.428770
# fr_bicyclic           0.000000
# fr_piperdine         11.267120
# fr_quatN              0.000000
# fr_unbrch_alkane      0.934085
#
# [76 rows x 1 columns]
#        False  True
# False   2516     6
# True      12   988
#        False  True
# False    808    34
# True      52   281
# 正解率(Accuracy) : 訓練 0.9948892674616695, 検証 0.9268085106382978
# 適合率(Precision) : 訓練 0.993963782696177, 検証 0.8920634920634921
# 再現率(Recall) : 訓練 0.988, 検証 0.8438438438438438
# F1スコア : 訓練 0.9909729187562688, 検証 0.8672839506172839
#  94%|=================== | 3303/3522 [00:12<00:00]

# %% [markdown]
# # mfi

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 91].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951     True
# 29952     True
# 29977    False
# 29978    False
# Name: mfi, Length: 4697, dtype: object
# mfi
# False    3502
# True     1195
# Name: count, dtype: int64
#                     importance
# Al / Si            1952.869834
# Na / Si             953.701124
# F / Si               35.392019
# H2O / Si            790.646011
# sda1 / Si           449.563026
# ...                        ...
# fr_Ndealkylation2    18.741020
# fr_bicyclic           5.201922
# fr_piperdine          2.334027
# fr_quatN              0.000000
# fr_unbrch_alkane      4.603513
#
# [76 rows x 1 columns]
#        False  True
# False   2619     7
# True      14   882
#        False  True
# False    848    28
# True      35   264
# 正解率(Accuracy) : 訓練 0.9940374787052811, 検証 0.9463829787234043
# 適合率(Precision) : 訓練 0.9921259842519685, 検証 0.9041095890410958
# 再現率(Recall) : 訓練 0.984375, 検証 0.882943143812709
# F1スコア : 訓練 0.9882352941176471, 検証 0.8934010152284264
#  94%|=================== | 3312/3522 [00:12<00:00]

# %% [markdown]
# # mtw

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 92].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951    False
# 29952    False
# 29977     True
# 29978     True
# Name: mtw, Length: 4697, dtype: object
# mtw
# False    4051
# True      646
# Name: count, dtype: int64
#                     importance
# Al / Si             891.294275
# Na / Si            1106.971691
# F / Si              101.252715
# H2O / Si            630.172181
# sda1 / Si           765.401851
# ...                        ...
# fr_Ndealkylation2    17.407960
# fr_bicyclic           0.000000
# fr_piperdine          8.440542
# fr_quatN              5.344430
# fr_unbrch_alkane      3.571886
#
# [76 rows x 1 columns]
#        False  True
# False   3036     2
# True       5   479
#        False  True
# False    998    15
# True      22   140
# 正解率(Accuracy) : 訓練 0.9980124929017604, 検証 0.9685106382978723
# 適合率(Precision) : 訓練 0.9958419958419958, 検証 0.9032258064516129
# 再現率(Recall) : 訓練 0.9896694214876033, 検証 0.8641975308641975
# F1スコア : 訓練 0.9927461139896373, 検証 0.8832807570977917
#  95%|=================== | 3337/3522 [00:13<00:00]

# %% [markdown]
# # ton

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 93].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: ton, Length: 4697, dtype: object
# ton
# False    4306
# True      391
# Name: count, dtype: int64
#                    importance
# Al / Si            615.939020
# Na / Si            499.767576
# F / Si              32.951589
# H2O / Si           929.695299
# sda1 / Si          399.325519
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic         97.212131
# fr_piperdine        15.234669
# fr_quatN             0.000000
# fr_unbrch_alkane     7.539523
#
# [76 rows x 1 columns]
#        False  True
# False   3229     0
# True       3   290
#        False  True
# False   1067    10
# True       9    89
# 正解率(Accuracy) : 訓練 0.9991482112436116, 検証 0.9838297872340426
# 適合率(Precision) : 訓練 1.0, 検証 0.898989898989899
# 再現率(Recall) : 訓練 0.9897610921501706, 検証 0.9081632653061225
# F1スコア : 訓練 0.9948542024013722, 検証 0.9035532994923858
#  94%|=================== | 3325/3522 [00:12<00:00]

# %% [markdown]
# # non

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 94].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: non, Length: 4697, dtype: object
# non
# False    4579
# True      118
# Name: count, dtype: int64
#                    importance
# Al / Si            189.253211
# Na / Si            307.605953
# F / Si             125.396994
# H2O / Si           121.315246
# sda1 / Si          110.368749
# ...                       ...
# fr_Ndealkylation2    0.074524
# fr_bicyclic          6.676495
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.253119
#
# [76 rows x 1 columns]
#        False  True
# False   3434     0
# True       0    88
#        False  True
# False   1142     3
# True       6    24
# 正解率(Accuracy) : 訓練 1.0, 検証 0.9923404255319149
# 適合率(Precision) : 訓練 1.0, 検証 0.8888888888888888
# 再現率(Recall) : 訓練 1.0, 検証 0.8
# F1スコア : 訓練 1.0, 検証 0.8421052631578947
#  94%|=================== | 3297/3522 [00:11<00:00]

# %% [markdown]
# # d8r

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 95].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: d8r, Length: 4697, dtype: object
# d8r
# False    4671
# True       26
# Name: count, dtype: int64
#                      importance
# Al / Si            1.116535e+02
# Na / Si            1.089272e+01
# F / Si             0.000000e+00
# H2O / Si           8.698493e+02
# sda1 / Si          4.726223e+01
# ...                         ...
# fr_Ndealkylation2  0.000000e+00
# fr_bicyclic        5.035970e-13
# fr_piperdine       0.000000e+00
# fr_quatN           0.000000e+00
# fr_unbrch_alkane   0.000000e+00
#
# [76 rows x 1 columns]
#        False  True
# False   3503     0
# True       1    18
#        False  True
# False   1168     0
# True       6     1
# 正解率(Accuracy) : 訓練 0.9997160704145373, 検証 0.9948936170212765
# 適合率(Precision) : 訓練 1.0, 検証 1.0
# 再現率(Recall) : 訓練 0.9473684210526315, 検証 0.14285714285714285
# F1スコア : 訓練 0.972972972972973, 検証 0.25

# %% [markdown]
# # can

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 96].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: can, Length: 4697, dtype: object
# can
# False    4543
# True      154
# Name: count, dtype: int64
#                    importance
# Al / Si            512.154629
# Na / Si            661.923649
# F / Si               0.000000
# H2O / Si           365.922894
# sda1 / Si          744.962086
# ...                       ...
# fr_Ndealkylation2    0.808374
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3406     1
# True       6   109
#        False  True
# False   1134     2
# True       8    31
# 正解率(Accuracy) : 訓練 0.9980124929017604, 検証 0.9914893617021276
# 適合率(Precision) : 訓練 0.990909090909091, 検証 0.9393939393939394
# 再現率(Recall) : 訓練 0.9478260869565217, 検証 0.7948717948717948
# F1スコア : 訓練 0.9688888888888889, 検証 0.8611111111111112
#  95%|=================== | 3349/3522 [00:11<00:00]

# %% [markdown]
# # phi

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 97].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: phi, Length: 4697, dtype: object
# phi
# False    4581
# True      116
# Name: count, dtype: int64
#                    importance
# Al / Si            869.047194
# Na / Si            515.357673
# F / Si             326.169583
# H2O / Si           230.937700
# sda1 / Si          211.364262
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3433     2
# True       1    86
#        False  True
# False   1138     8
# True       5    24
# 正解率(Accuracy) : 訓練 0.9991482112436116, 検証 0.9889361702127659
# 適合率(Precision) : 訓練 0.9772727272727273, 検証 0.75
# 再現率(Recall) : 訓練 0.9885057471264368, 検証 0.8275862068965517
# F1スコア : 訓練 0.9828571428571429, 検証 0.7868852459016393

# %% [markdown]
# # sod

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 98].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: sod, Length: 4697, dtype: object
# sod
# False    4395
# True      302
# Name: count, dtype: int64
#                     importance
# Al / Si            2036.298837
# Na / Si             690.608346
# F / Si                0.000000
# H2O / Si            482.527095
# sda1 / Si           658.380321
# ...                        ...
# fr_Ndealkylation2     0.000000
# fr_bicyclic           0.000000
# fr_piperdine          0.368436
# fr_quatN              0.000000
# fr_unbrch_alkane      3.193982
#
# [76 rows x 1 columns]
#        False  True
# False   3292     4
# True       5   221
#        False  True
# False   1083    16
# True      15    61
# 正解率(Accuracy) : 訓練 0.9974446337308348, 検証 0.9736170212765958
# 適合率(Precision) : 訓練 0.9822222222222222, 検証 0.7922077922077922
# 再現率(Recall) : 訓練 0.9778761061946902, 検証 0.8026315789473685
# F1スコア : 訓練 0.9800443458980045, 検証 0.7973856209150327
#  94%|=================== | 3321/3522 [00:11<00:00]

# %% [markdown]
# # gme

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 99].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251       True
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: gme, Length: 4697, dtype: object
# gme
# False    4529
# True      168
# Name: count, dtype: int64
#                    importance
# Al / Si            626.152880
# Na / Si            975.017052
# F / Si               0.000000
# H2O / Si           653.912023
# sda1 / Si          210.515592
# ...                       ...
# fr_Ndealkylation2    0.944547
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3391     5
# True       8   118
#        False  True
# False   1126     7
# True       7    35
# 正解率(Accuracy) : 訓練 0.9963089153889836, 検証 0.9880851063829788
# 適合率(Precision) : 訓練 0.959349593495935, 検証 0.8333333333333334
# 再現率(Recall) : 訓練 0.9365079365079365, 検証 0.8333333333333334
# F1スコア : 訓練 0.9477911646586346, 検証 0.8333333333333334
#  93%|=================== | 3269/3522 [00:11<00:00]

# %% [markdown]
# # pau

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 100].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: pau, Length: 4697, dtype: object
# pau
# False    4671
# True       26
# Name: count, dtype: int64
#                      importance
# Al / Si            9.379423e+01
# Na / Si            6.385915e+01
# F / Si             0.000000e+00
# H2O / Si           1.531167e+02
# sda1 / Si          7.233824e+01
# ...                         ...
# fr_Ndealkylation2  1.189950e-11
# fr_bicyclic        0.000000e+00
# fr_piperdine       0.000000e+00
# fr_quatN           0.000000e+00
# fr_unbrch_alkane   0.000000e+00
#
# [76 rows x 1 columns]
#        False  True
# False   3503     0
# True       1    18
#        False  True
# False   1168     0
# True       6     1
# 正解率(Accuracy) : 訓練 0.9997160704145373, 検証 0.9948936170212765
# 適合率(Precision) : 訓練 1.0, 検証 1.0
# 再現率(Recall) : 訓練 0.9473684210526315, 検証 0.14285714285714285
# F1スコア : 訓練 0.972972972972973, 検証 0.25

# %% [markdown]
# # lta

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 101].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: lta, Length: 4697, dtype: object
# lta
# False    4577
# True      120
# Name: count, dtype: int64
#                     importance
# Al / Si            1166.676132
# Na / Si             682.026330
# F / Si                0.000000
# H2O / Si            175.974752
# sda1 / Si           216.969705
# ...                        ...
# fr_Ndealkylation2     0.000000
# fr_bicyclic           0.000000
# fr_piperdine          0.000000
# fr_quatN              0.000000
# fr_unbrch_alkane      0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3432     0
# True       0    90
#        False  True
# False   1139     6
# True       6    24
# 正解率(Accuracy) : 訓練 1.0, 検証 0.9897872340425532
# 適合率(Precision) : 訓練 1.0, 検証 0.8
# 再現率(Recall) : 訓練 1.0, 検証 0.8
# F1スコア : 訓練 1.0, 検証 0.8

# %% [markdown]
# # jbw

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU_jbw.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 102].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: jbw, Length: 4697, dtype: object
# jbw
# False    4148
# True      549
# Name: count, dtype: int64
#                     importance
# Al / Si            2544.960149
# Na / Si             779.248238
# F / Si               20.430281
# H2O / Si           1219.907804
# sda1 / Si           462.735671
# ...                        ...
# fr_Ndealkylation2     0.000000
# fr_bicyclic           0.000000
# fr_piperdine         47.060862
# fr_quatN              0.000000
# fr_unbrch_alkane      2.820843
#
# [76 rows x 1 columns]
#        False  True
# False   3107     3
# True       3   409
#        False  True
# False   1021    17
# True      24   113
# 正解率(Accuracy) : 訓練 0.9982964224872232, 検証 0.9651063829787234
# 適合率(Precision) : 訓練 0.9927184466019418, 検証 0.8692307692307693
# 再現率(Recall) : 訓練 0.9927184466019418, 検証 0.8248175182481752
# F1スコア : 訓練 0.9927184466019418, 検証 0.846441947565543
#  99%|===================| 3473/3522 [00:13<00:00]
