# %% [markdown]
# # mor

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 84].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_mor_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_mor_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951     True
# 29952     True
# 29977     True
# 29978     True
# Name: mor, Length: 4697, dtype: object
# mor
# False    2755
# True     1942
# Name: count, dtype: int64
# 最適な深さ: 9
# 最適な最小サンプル数: 2
#                    importance
# MaxEStateIndex       0.002167
# MinAbsEStateIndex    0.005975
# MinEStateIndex       0.097431
# qed                  0.017570
# SPS                  0.000837
# ...                       ...
# fr_Ndealkylation2    0.002178
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [68 rows x 1 columns]
#        False  True
# False   1806   260
# True     257  1199
#        False  True
# False    584   105
# True      99   387
# 正解率(Accuracy) : 訓練 0.8532084043157298, 検証 0.8263829787234043
# 適合率(Precision) : 訓練 0.8217957505140507, 検証 0.7865853658536586
# 再現率(Recall) : 訓練 0.823489010989011, 検証 0.7962962962962963
# F1スコア : 訓練 0.8226415094339623, 検証 0.7914110429447853
# 'rdkit_mor_only.pdf'

# %% [markdown]
# # bea

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 85].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_bea_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_bea_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951    False
# 29952    False
# 29977     True
# 29978     True
# Name: bea, Length: 4697, dtype: object
# bea
# False    4233
# True      464
# Name: count, dtype: int64
# 最適な深さ: 16
# 最適な最小サンプル数: 1
#                    importance
# MaxEStateIndex       0.129754
# MinAbsEStateIndex    0.000000
# MinEStateIndex       0.000080
# qed                  0.000000
# SPS                  0.196723
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000100
# fr_piperdine         0.003113
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [68 rows x 1 columns]
#        False  True
# False   3031   143
# True      38   310
#        False  True
# False    989    70
# True      16   100
# 正解率(Accuracy) : 訓練 0.9486087450312323, 検証 0.9268085106382978
# 適合率(Precision) : 訓練 0.6843267108167771, 検証 0.5882352941176471
# 再現率(Recall) : 訓練 0.8908045977011494, 検証 0.8620689655172413
# F1スコア : 訓練 0.7740324594257179, 検証 0.6993006993006993
# 'rdkit_bea_only.pdf'

# %% [markdown]
# # mtt

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 86].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_mtt_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_mtt_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: mtt, Length: 4697, dtype: object
# mtt
# False    4192
# True      505
# Name: count, dtype: int64
# 最適な深さ: 40
# 最適な最小サンプル数: 1
#                    importance
# MaxEStateIndex       0.000000
# MinAbsEStateIndex    0.000582
# MinEStateIndex       0.122603
# qed                  0.059543
# SPS                  0.350314
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [68 rows x 1 columns]
#        False  True
# False   3006   137
# True      99   280
#        False  True
# False    993    56
# True      25   101
# 正解率(Accuracy) : 訓練 0.9329926178307779, 検証 0.931063829787234
# 適合率(Precision) : 訓練 0.6714628297362111, 検証 0.643312101910828
# 再現率(Recall) : 訓練 0.7387862796833773, 検証 0.8015873015873016
# F1スコア : 訓練 0.7035175879396985, 検証 0.7137809187279152
# 'rdkit_mtt_only.pdf'

# %% [markdown]
# # cas

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 87].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_cas_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_cas_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951     True
# 29952     True
# 29977    False
# 29978    False
# Name: cas, Length: 4697, dtype: object
# cas
# False    3357
# True     1340
# Name: count, dtype: int64
# 最適な深さ: 26
# 最適な最小サンプル数: 3
#                    importance
# MaxEStateIndex       0.000078
# MinAbsEStateIndex    0.000891
# MinEStateIndex       0.030120
# qed                  0.021343
# SPS                  0.004767
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000977
# fr_piperdine         0.000020
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000750
#
# [68 rows x 1 columns]
#        False  True
# False   2389   128
# True     251   754
#        False  True
# False    802    38
# True      97   238
# 正解率(Accuracy) : 訓練 0.8923906871095968, 検証 0.8851063829787233
# 適合率(Precision) : 訓練 0.854875283446712, 検証 0.8623188405797102
# 再現率(Recall) : 訓練 0.7502487562189055, 検証 0.7104477611940299
# F1スコア : 訓練 0.7991520932697403, 検証 0.779050736497545
# 'rdkit_cas_only.pdf'

# %% [markdown]
# # d6r

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 88].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_d6r_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_d6r_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251       True
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: d6r, Length: 4697, dtype: object
# d6r
# False    3705
# True      992
# Name: count, dtype: int64
# 最適な深さ: 23
# 最適な最小サンプル数: 1
#                    importance
# MaxEStateIndex       0.031419
# MinAbsEStateIndex    0.000402
# MinEStateIndex       0.000000
# qed                  0.001592
# SPS                  0.009461
# ...                       ...
# fr_Ndealkylation2    0.000632
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000468
# fr_unbrch_alkane     0.000000
#
# [68 rows x 1 columns]
#        False  True
# False   2709    69
# True     275   469
#        False  True
# False    900    27
# True      94   154
# 正解率(Accuracy) : 訓練 0.902328222600795, 検証 0.8970212765957447
# 適合率(Precision) : 訓練 0.8717472118959108, 検証 0.850828729281768
# 再現率(Recall) : 訓練 0.6303763440860215, 検証 0.6209677419354839
# F1スコア : 訓練 0.7316692667706708, 検証 0.717948717948718
# 'rdkit_d6r_only.pdf'

# %% [markdown]
# # fer

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 89].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_fer_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_fer_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: fer, Length: 4697, dtype: object
# fer
# False    4455
# True      242
# Name: count, dtype: int64
# 最適な深さ: 11
# 最適な最小サンプル数: 6
#                    importance
# MaxEStateIndex       0.017556
# MinAbsEStateIndex    0.223784
# MinEStateIndex       0.138622
# qed                  0.000302
# SPS                  0.000000
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [68 rows x 1 columns]
#        False  True
# False   3303    38
# True     101    80
#        False  True
# False   1098    16
# True      35    26
# 正解率(Accuracy) : 訓練 0.9605337876206701, 検証 0.9565957446808511
# 適合率(Precision) : 訓練 0.6779661016949152, 検証 0.6190476190476191
# 再現率(Recall) : 訓練 0.4419889502762431, 検証 0.4262295081967213
# F1スコア : 訓練 0.5351170568561873, 検証 0.5048543689320388
# 'rdkit_fer_only.pdf'

# %% [markdown]
# # mel

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 90].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_mel_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_mel_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951     True
# 29952     True
# 29977    False
# 29978    False
# Name: mel, Length: 4697, dtype: object
# mel
# False    3364
# True     1333
# Name: count, dtype: int64
# 最適な深さ: 66
# 最適な最小サンプル数: 2
#                    importance
# MaxEStateIndex       0.005529
# MinAbsEStateIndex    0.002785
# MinEStateIndex       0.001418
# qed                  0.004503
# SPS                  0.004004
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000001
#
# [68 rows x 1 columns]
#        False  True
# False   2411   111
# True     227   773
#        False  True
# False    798    44
# True      96   237
# 正解率(Accuracy) : 訓練 0.9040318001135719, 検証 0.8808510638297873
# 適合率(Precision) : 訓練 0.8744343891402715, 検証 0.8434163701067615
# 再現率(Recall) : 訓練 0.773, 検証 0.7117117117117117
# F1スコア : 訓練 0.8205944798301487, 検証 0.7719869706840391
# 'rdkit_mel_only.pdf'

# %% [markdown]
# # mfi

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 91].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_mfi_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_mfi_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951     True
# 29952     True
# 29977    False
# 29978    False
# Name: mfi, Length: 4697, dtype: object
# mfi
# False    3502
# True     1195
# Name: count, dtype: int64
# 最適な深さ: 20
# 最適な最小サンプル数: 1
#                      importance
# MaxEStateIndex     3.446568e-03
# MinAbsEStateIndex  1.574711e-03
# MinEStateIndex     5.971652e-03
# qed                0.000000e+00
# SPS                5.474264e-05
# ...                         ...
# fr_Ndealkylation2  3.188091e-03
# fr_bicyclic        0.000000e+00
# fr_piperdine       0.000000e+00
# fr_quatN           0.000000e+00
# fr_unbrch_alkane   1.138799e-07
#
# [68 rows x 1 columns]
#        False  True
# False   2536    90
# True     193   703
#        False  True
# False    840    36
# True      75   224
# 正解率(Accuracy) : 訓練 0.9196479273140261, 検証 0.9055319148936171
# 適合率(Precision) : 訓練 0.8865069356872636, 検証 0.8615384615384616
# 再現率(Recall) : 訓練 0.7845982142857143, 検証 0.7491638795986622
# F1スコア : 訓練 0.8324452338661931, 検証 0.8014311270125224
# 'rdkit_mfi_only.pdf'

# %% [markdown]
# # mtw

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 92].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_mtw_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_mtw_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951    False
# 29952    False
# 29977     True
# 29978     True
# Name: mtw, Length: 4697, dtype: object
# mtw
# False    4051
# True      646
# Name: count, dtype: int64
# 最適な深さ: 65
# 最適な最小サンプル数: 1
#                    importance
# MaxEStateIndex       0.009495
# MinAbsEStateIndex    0.046998
# MinEStateIndex       0.007527
# qed                  0.000000
# SPS                  0.002280
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [68 rows x 1 columns]
#        False  True
# False   2898   140
# True      60   424
#        False  True
# False    966    47
# True      33   129
# 正解率(Accuracy) : 訓練 0.9432140829074389, 検証 0.9319148936170213
# 適合率(Precision) : 訓練 0.75177304964539, 検証 0.7329545454545454
# 再現率(Recall) : 訓練 0.8760330578512396, 検証 0.7962962962962963
# F1スコア : 訓練 0.8091603053435115, 検証 0.7633136094674556
# 'rdkit_mtw_only.pdf'

# %% [markdown]
# # ton

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 93].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_ton_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_ton_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: ton, Length: 4697, dtype: object
# ton
# False    4306
# True      391
# Name: count, dtype: int64
# 最適な深さ: 22
# 最適な最小サンプル数: 1
#                    importance
# MaxEStateIndex       0.000000
# MinAbsEStateIndex    0.000033
# MinEStateIndex       0.000977
# qed                  0.000504
# SPS                  0.344612
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.004790
# fr_piperdine         0.000000
# fr_quatN             0.000030
# fr_unbrch_alkane     0.000000
#
# [68 rows x 1 columns]
#        False  True
# False   3147    82
# True      86   207
#        False  True
# False   1039    38
# True      33    65
# 正解率(Accuracy) : 訓練 0.9522998296422487, 検証 0.9395744680851064
# 適合率(Precision) : 訓練 0.7162629757785467, 検証 0.6310679611650486
# 再現率(Recall) : 訓練 0.7064846416382252, 検証 0.6632653061224489
# F1スコア : 訓練 0.711340206185567, 検証 0.6467661691542289
# 'rdkit_ton_only.pdf'

# %% [markdown]
# # non

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 94].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_non_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_non_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: non, Length: 4697, dtype: object
# non
# False    4579
# True      118
# Name: count, dtype: int64
# 最適な深さ: 8
# 最適な最小サンプル数: 1
#                    importance
# MaxEStateIndex       0.000000
# MinAbsEStateIndex    0.028211
# MinEStateIndex       0.002309
# qed                  0.064199
# SPS                  0.000000
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.003110
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [68 rows x 1 columns]
#        False  True
# False   3413    21
# True      27    61
#        False  True
# False   1136     9
# True       8    22
# 正解率(Accuracy) : 訓練 0.9863713798977853, 検証 0.985531914893617
# 適合率(Precision) : 訓練 0.7439024390243902, 検証 0.7096774193548387
# 再現率(Recall) : 訓練 0.6931818181818182, 検証 0.7333333333333333
# F1スコア : 訓練 0.7176470588235294, 検証 0.7213114754098361
# 'rdkit_non_only.pdf'

# %% [markdown]
# # d8r

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 95].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_d8r_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_d8r_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: d8r, Length: 4697, dtype: object
# d8r
# False    4671
# True       26
# Name: count, dtype: int64
# 最適な深さ: 1
# 最適な最小サンプル数: 1
#                    importance
# MaxEStateIndex            0.0
# MinAbsEStateIndex         0.0
# MinEStateIndex            0.0
# qed                       0.0
# SPS                       0.0
# ...                       ...
# fr_Ndealkylation2         0.0
# fr_bicyclic               0.0
# fr_piperdine              0.0
# fr_quatN                  0.0
# fr_unbrch_alkane          0.0
#
# [68 rows x 1 columns]
# C:\Users\yamamoto02\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#        False  True
# False   3503     0
# True      19     0
# C:\Users\yamamoto02\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#        False  True
# False   1168     0
# True       7     0
# 正解率(Accuracy) : 訓練 0.9946053378762068, 検証 0.9940425531914894
# 適合率(Precision) : 訓練 0.0, 検証 0.0
# 再現率(Recall) : 訓練 0.0, 検証 0.0
# F1スコア : 訓練 0.0, 検証 0.0
# 'rdkit_d8r_only.pdf'

# %% [markdown]
# # can

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 96].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_can_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_can_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: can, Length: 4697, dtype: object
# can
# False    4543
# True      154
# Name: count, dtype: int64
# 最適な深さ: 5
# 最適な最小サンプル数: 5
#                    importance
# MaxEStateIndex       0.143574
# MinAbsEStateIndex    0.000000
# MinEStateIndex       0.000000
# qed                  0.000000
# SPS                  0.027419
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [68 rows x 1 columns]
#        False  True
# False   3407     0
# True     107     8
#        False  True
# False   1135     1
# True      38     1
# 正解率(Accuracy) : 訓練 0.9696195343554799, 検証 0.9668085106382979
# 適合率(Precision) : 訓練 1.0, 検証 0.5
# 再現率(Recall) : 訓練 0.06956521739130435, 検証 0.02564102564102564
# F1スコア : 訓練 0.13008130081300814, 検証 0.04878048780487805
# 'rdkit_can_only.pdf'

# %% [markdown]
# # phi

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 97].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_phi_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_phi_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: phi, Length: 4697, dtype: object
# phi
# False    4581
# True      116
# Name: count, dtype: int64
# 最適な深さ: 1
# 最適な最小サンプル数: 1
#                    importance
# MaxEStateIndex            0.0
# MinAbsEStateIndex         0.0
# MinEStateIndex            0.0
# qed                       0.0
# SPS                       0.0
# ...                       ...
# fr_Ndealkylation2         0.0
# fr_bicyclic               0.0
# fr_piperdine              0.0
# fr_quatN                  0.0
# fr_unbrch_alkane          0.0
#
# [68 rows x 1 columns]
# C:\Users\yamamoto02\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#        False  True
# False   3435     0
# True      87     0
# C:\Users\yamamoto02\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#        False  True
# False   1146     0
# True      29     0
# 正解率(Accuracy) : 訓練 0.975298126064736, 検証 0.9753191489361702
# 適合率(Precision) : 訓練 0.0, 検証 0.0
# 再現率(Recall) : 訓練 0.0, 検証 0.0
# F1スコア : 訓練 0.0, 検証 0.0
# 'rdkit_phi_only.pdf'

# %% [markdown]
# # sod

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 98].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_sod_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_sod_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: sod, Length: 4697, dtype: object
# sod
# False    4395
# True      302
# Name: count, dtype: int64
# 最適な深さ: 6
# 最適な最小サンプル数: 3
#                    importance
# MaxEStateIndex       0.000000
# MinAbsEStateIndex    0.000000
# MinEStateIndex       0.000000
# qed                  0.000000
# SPS                  0.014346
# ...                       ...
# fr_Ndealkylation2    0.000404
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [68 rows x 1 columns]
#        False  True
# False   3293     3
# True     182    44
#        False  True
# False   1095     4
# True      65    11
# 正解率(Accuracy) : 訓練 0.947473026689381, 検証 0.9412765957446808
# 適合率(Precision) : 訓練 0.9361702127659575, 検証 0.7333333333333333
# 再現率(Recall) : 訓練 0.19469026548672566, 検証 0.14473684210526316
# F1スコア : 訓練 0.32234432234432236, 検証 0.24175824175824176
# 'rdkit_sod_only.pdf'

# %% [markdown]
# # gme

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 99].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_gme_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_gme_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251       True
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: gme, Length: 4697, dtype: object
# gme
# False    4529
# True      168
# Name: count, dtype: int64
# 最適な深さ: 6
# 最適な最小サンプル数: 1
#                    importance
# MaxEStateIndex       0.078511
# MinAbsEStateIndex    0.000000
# MinEStateIndex       0.000000
# qed                  0.000000
# SPS                  0.000000
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [68 rows x 1 columns]
#        False  True
# False   3395     1
# True     120     6
#        False  True
# False   1132     1
# True      40     2
# 正解率(Accuracy) : 訓練 0.9656445201590006, 検証 0.9651063829787234
# 適合率(Precision) : 訓練 0.8571428571428571, 検証 0.6666666666666666
# 再現率(Recall) : 訓練 0.047619047619047616, 検証 0.047619047619047616
# F1スコア : 訓練 0.09022556390977443, 検証 0.08888888888888889
# 'rdkit_gme_only.pdf'

# %% [markdown]
# # pau

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 100].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_pau_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_pau_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: pau, Length: 4697, dtype: object
# pau
# False    4671
# True       26
# Name: count, dtype: int64
# 最適な深さ: 1
# 最適な最小サンプル数: 1
#                    importance
# MaxEStateIndex            0.0
# MinAbsEStateIndex         0.0
# MinEStateIndex            0.0
# qed                       0.0
# SPS                       0.0
# ...                       ...
# fr_Ndealkylation2         0.0
# fr_bicyclic               0.0
# fr_piperdine              0.0
# fr_quatN                  0.0
# fr_unbrch_alkane          0.0
#
# [68 rows x 1 columns]
#        False  True
# False   3500     3
# True      10     9
# C:\Users\yamamoto02\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#        False  True
# False   1168     0
# True       7     0
# 正解率(Accuracy) : 訓練 0.9963089153889836, 検証 0.9940425531914894
# 適合率(Precision) : 訓練 0.75, 検証 0.0
# 再現率(Recall) : 訓練 0.47368421052631576, 検証 0.0
# F1スコア : 訓練 0.5806451612903226, 検証 0.0
# 'rdkit_pau_only.pdf'

# %% [markdown]
# # lta

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 101].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_lta_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_lta_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: lta, Length: 4697, dtype: object
# lta
# False    4577
# True      120
# Name: count, dtype: int64
# 最適な深さ: 2
# 最適な最小サンプル数: 1
#                    importance
# MaxEStateIndex            0.0
# MinAbsEStateIndex         0.0
# MinEStateIndex            0.0
# qed                       0.0
# SPS                       0.0
# ...                       ...
# fr_Ndealkylation2         0.0
# fr_bicyclic               0.0
# fr_piperdine              0.0
# fr_quatN                  0.0
# fr_unbrch_alkane          0.0
#
# [68 rows x 1 columns]
#        False  True
# False   3431     1
# True      81     9
#        False  True
# False   1143     2
# True      30     0
# 正解率(Accuracy) : 訓練 0.97671777399205, 検証 0.9727659574468085
# 適合率(Precision) : 訓練 0.9, 検証 0.0
# 再現率(Recall) : 訓練 0.1, 検証 0.0
# F1スコア : 訓練 0.18, 検証 0.0
# 'rdkit_lta_only.pdf'

# %% [markdown]
# # jbw

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU_jbw.csv', index_col=0, header=0)
x=dataset.iloc[:, 8:76]
y=dataset.iloc[:, 102].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_jbw_only', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_jbw_only'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: jbw, Length: 4697, dtype: object
# jbw
# False    4148
# True      549
# Name: count, dtype: int64
# 最適な深さ: 8
# 最適な最小サンプル数: 3
#                    importance
# MaxEStateIndex       0.089608
# MinAbsEStateIndex    0.008211
# MinEStateIndex       0.053259
# qed                  0.004973
# SPS                  0.279777
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.012991
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [68 rows x 1 columns]
#        False  True
# False   3030    80
# True     188   224
#        False  True
# False    998    40
# True      64    73
# 正解率(Accuracy) : 訓練 0.9239068710959683, 検証 0.9114893617021277
# 適合率(Precision) : 訓練 0.7368421052631579, 検証 0.6460176991150443
# 再現率(Recall) : 訓練 0.5436893203883495, 検証 0.5328467153284672
# F1スコア : 訓練 0.6256983240223464, 検証 0.584
# 'rdkit_jbw_only.pdf'
