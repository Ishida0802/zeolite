# %% [markdown]
# # mor

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 84].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_mor', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_mor'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951     True
# 29952     True
# 29977     True
# 29978     True
# Name: mor, Length: 4697, dtype: object
# mor
# False    2755
# True     1942
# Name: count, dtype: int64
# 最適な深さ: 42
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.124103
# Na / Si              0.079914
# F / Si               0.005522
# H2O / Si             0.039526
# sda1 / Si            0.052188
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   2060     6
# True      17  1439
#        False  True
# False    631    58
# True      53   433
# 正解率(Accuracy) : 訓練 0.9934696195343555, 検証 0.9055319148936171
# 適合率(Precision) : 訓練 0.995847750865052, 検証 0.8818737270875764
# 再現率(Recall) : 訓練 0.9883241758241759, 検証 0.8909465020576132
# F1スコア : 訓練 0.9920716994139952, 検証 0.8863868986693961
# 'rdkit_mor.pdf'

# %% [markdown]
# # bea

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 85].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_bea', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_bea'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951    False
# 29952    False
# 29977     True
# 29978     True
# Name: bea, Length: 4697, dtype: object
# bea
# False    4233
# True      464
# Name: count, dtype: int64
# 最適な深さ: 15
# 最適な最小サンプル数: 2
#                    importance
# Al / Si              0.086115
# Na / Si              0.052968
# F / Si               0.000000
# H2O / Si             0.060302
# sda1 / Si            0.085207
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.002076
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3170     4
# True      25   323
#        False  True
# False   1038    21
# True      16   100
# 正解率(Accuracy) : 訓練 0.9917660420215787, 検証 0.9685106382978723
# 適合率(Precision) : 訓練 0.9877675840978594, 検証 0.8264462809917356
# 再現率(Recall) : 訓練 0.9281609195402298, 検証 0.8620689655172413
# F1スコア : 訓練 0.957037037037037, 検証 0.8438818565400844
# 'rdkit_bea.pdf'

# %% [markdown]
# # mtt

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 86].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_bea', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_bea'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: mtt, Length: 4697, dtype: object
# mtt
# False    4192
# True      505
# Name: count, dtype: int64
# 最適な深さ: 41
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.065933
# Na / Si              0.116996
# F / Si               0.033766
# H2O / Si             0.047854
# sda1 / Si            0.069749
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3143     0
# True       6   373
#        False  True
# False   1029    20
# True      24   102
# 正解率(Accuracy) : 訓練 0.9982964224872232, 検証 0.9625531914893617
# 適合率(Precision) : 訓練 1.0, 検証 0.8360655737704918
# 再現率(Recall) : 訓練 0.9841688654353562, 検証 0.8095238095238095
# F1スコア : 訓練 0.9920212765957447, 検証 0.8225806451612904
# 'rdkit_bea.pdf'

# %% [markdown]
# # cas

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 87].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_cas', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_cas'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951     True
# 29952     True
# 29977    False
# 29978    False
# Name: cas, Length: 4697, dtype: object
# cas
# False    3357
# True     1340
# Name: count, dtype: int64
# 最適な深さ: 62
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.180787
# Na / Si              0.065538
# F / Si               0.001361
# H2O / Si             0.045831
# sda1 / Si            0.021906
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.001843
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000922
#
# [76 rows x 1 columns]
#        False  True
# False   2515     2
# True      10   995
#        False  True
# False    801    39
# True      51   284
# 正解率(Accuracy) : 訓練 0.9965928449744463, 検証 0.9234042553191489
# 適合率(Precision) : 訓練 0.9979939819458375, 検証 0.8792569659442725
# 再現率(Recall) : 訓練 0.9900497512437811, 検証 0.8477611940298507
# F1スコア : 訓練 0.994005994005994, 検証 0.8632218844984803
# 'rdkit_cas.pdf'

# %% [markdown]
# # d6r

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 88].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_d6r', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_d6r'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251       True
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: d6r, Length: 4697, dtype: object
# d6r
# False    3705
# True      992
# Name: count, dtype: int64
# 最適な深さ: 42
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.096409
# Na / Si              0.040437
# F / Si               0.002573
# H2O / Si             0.076743
# sda1 / Si            0.058085
# ...                       ...
# fr_Ndealkylation2    0.000155
# fr_bicyclic          0.000000
# fr_piperdine         0.001385
# fr_quatN             0.002296
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   2776     2
# True       9   735
#        False  True
# False    888    39
# True      43   205
# 正解率(Accuracy) : 訓練 0.9968767745599092, 検証 0.9302127659574468
# 適合率(Precision) : 訓練 0.9972862957937585, 検証 0.8401639344262295
# 再現率(Recall) : 訓練 0.9879032258064516, 検証 0.8266129032258065
# F1スコア : 訓練 0.9925725860904794, 検証 0.8333333333333334
# 'rdkit_d6r.pdf'

# %% [markdown]
# # fer

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 89].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_fer', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_fer'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: fer, Length: 4697, dtype: object
# fer
# False    4455
# True      242
# Name: count, dtype: int64
# 最適な深さ: 10
# 最適な最小サンプル数: 4
#                    importance
# Al / Si              0.177189
# Na / Si              0.187365
# F / Si               0.005618
# H2O / Si             0.016235
# sda1 / Si            0.081744
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3333     8
# True      55   126
#        False  True
# False   1110     4
# True      23    38
# 正解率(Accuracy) : 訓練 0.9821124361158433, 検証 0.9770212765957447
# 適合率(Precision) : 訓練 0.9402985074626866, 検証 0.9047619047619048
# 再現率(Recall) : 訓練 0.6961325966850829, 検証 0.6229508196721312
# F1スコア : 訓練 0.8, 検証 0.7378640776699029
# 'rdkit_fer.pdf'

# %% [markdown]
# # mel

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 90].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_mel', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_mel'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951     True
# 29952     True
# 29977    False
# 29978    False
# Name: mel, Length: 4697, dtype: object
# mel
# False    3364
# True     1333
# Name: count, dtype: int64
# 最適な深さ: 35
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.115734
# Na / Si              0.056721
# F / Si               0.000000
# H2O / Si             0.024210
# sda1 / Si            0.037104
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.003130
#
# [76 rows x 1 columns]
#        False  True
# False   2518     4
# True       4   996
#        False  True
# False    800    42
# True      43   290
# 正解率(Accuracy) : 訓練 0.9977285633162976, 検証 0.9276595744680851
# 適合率(Precision) : 訓練 0.996, 検証 0.8734939759036144
# 再現率(Recall) : 訓練 0.996, 検証 0.8708708708708709
# F1スコア : 訓練 0.996, 検証 0.8721804511278195
# 'rdkit_mel.pdf'

# %% [markdown]
# # mfi

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 91].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_mfi', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_mfi'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951     True
# 29952     True
# 29977    False
# 29978    False
# Name: mfi, Length: 4697, dtype: object
# mfi
# False    3502
# True     1195
# Name: count, dtype: int64
# 最適な深さ: 66
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.094661
# Na / Si              0.062791
# F / Si               0.003750
# H2O / Si             0.022192
# sda1 / Si            0.032689
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   2623     3
# True       7   889
#        False  True
# False    838    38
# True      36   263
# 正解率(Accuracy) : 訓練 0.997160704145372, 検証 0.9370212765957446
# 適合率(Precision) : 訓練 0.9966367713004485, 検証 0.8737541528239202
# 再現率(Recall) : 訓練 0.9921875, 検証 0.8795986622073578
# F1スコア : 訓練 0.9944071588366891, 検証 0.8766666666666667
# 'rdkit_mfi.pdf'

# %% [markdown]
# # mtw

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 92].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_mtw', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_mtw'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951    False
# 29952    False
# 29977     True
# 29978     True
# Name: mtw, Length: 4697, dtype: object
# mtw
# False    4051
# True      646
# Name: count, dtype: int64
# 最適な深さ: 50
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.077988
# Na / Si              0.116740
# F / Si               0.003074
# H2O / Si             0.057060
# sda1 / Si            0.059256
# ...                       ...
# fr_Ndealkylation2    0.004586
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.001341
# fr_unbrch_alkane     0.001130
#
# [76 rows x 1 columns]
#        False  True
# False   3037     1
# True       6   478
#        False  True
# False    990    23
# True      26   136
# 正解率(Accuracy) : 訓練 0.9980124929017604, 検証 0.9582978723404255
# 適合率(Precision) : 訓練 0.9979123173277662, 検証 0.8553459119496856
# 再現率(Recall) : 訓練 0.987603305785124, 検証 0.8395061728395061
# F1スコア : 訓練 0.9927310488058152, 検証 0.8473520249221184
# 'rdkit_mtw.pdf'

# %% [markdown]
# # ton

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 93].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_ton', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_ton'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: ton, Length: 4697, dtype: object
# ton
# False    4306
# True      391
# Name: count, dtype: int64
# 最適な深さ: 32
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.064333
# Na / Si              0.095501
# F / Si               0.006334
# H2O / Si             0.122093
# sda1 / Si            0.044327
# ...                       ...
# fr_Ndealkylation2    0.003285
# fr_bicyclic          0.002928
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3229     0
# True       3   290
#        False  True
# False   1061    16
# True      11    87
# 正解率(Accuracy) : 訓練 0.9991482112436116, 検証 0.9770212765957447
# 適合率(Precision) : 訓練 1.0, 検証 0.8446601941747572
# 再現率(Recall) : 訓練 0.9897610921501706, 検証 0.8877551020408163
# F1スコア : 訓練 0.9948542024013722, 検証 0.8656716417910447
# 'rdkit_ton.pdf'

# %% [markdown]
# # non

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 94].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_non', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_non'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: non, Length: 4697, dtype: object
# non
# False    4579
# True      118
# Name: count, dtype: int64
# 最適な深さ: 10
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.043718
# Na / Si              0.051794
# F / Si               0.004950
# H2O / Si             0.038073
# sda1 / Si            0.025630
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000377
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3434     0
# True       4    84
#        False  True
# False   1137     8
# True       5    25
# 正解率(Accuracy) : 訓練 0.9988642816581488, 検証 0.9889361702127659
# 適合率(Precision) : 訓練 1.0, 検証 0.7575757575757576
# 再現率(Recall) : 訓練 0.9545454545454546, 検証 0.8333333333333334
# F1スコア : 訓練 0.9767441860465116, 検証 0.7936507936507936
# 'rdkit_non.pdf'

# %% [markdown]
# # d8r

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 95].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_d8r', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_d8r'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: d8r, Length: 4697, dtype: object
# d8r
# False    4671
# True       26
# Name: count, dtype: int64
# 最適な深さ: 2
# 最適な最小サンプル数: 1
#                    importance
# Al / Si                   0.0
# Na / Si                   0.0
# F / Si                    0.0
# H2O / Si                  0.0
# sda1 / Si                 0.0
# ...                       ...
# fr_Ndealkylation2         0.0
# fr_bicyclic               0.0
# fr_piperdine              0.0
# fr_quatN                  0.0
# fr_unbrch_alkane          0.0
#
# [76 rows x 1 columns]
#        False  True
# False   3502     1
# True       7    12
#        False  True
# False   1168     0
# True       6     1
# 正解率(Accuracy) : 訓練 0.9977285633162976, 検証 0.9948936170212765
# 適合率(Precision) : 訓練 0.9230769230769231, 検証 1.0
# 再現率(Recall) : 訓練 0.631578947368421, 検証 0.14285714285714285
# F1スコア : 訓練 0.75, 検証 0.25
# 'rdkit_d8r.pdf'

# %% [markdown]
# # can

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 96].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_can', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_can'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: can, Length: 4697, dtype: object
# can
# False    4543
# True      154
# Name: count, dtype: int64
# 最適な深さ: 6
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.000000
# Na / Si              0.157504
# F / Si               0.000000
# H2O / Si             0.045484
# sda1 / Si            0.219157
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3405     2
# True      32    83
#        False  True
# False   1134     2
# True      18    21
# 正解率(Accuracy) : 訓練 0.9903463940942646, 検証 0.9829787234042553
# 適合率(Precision) : 訓練 0.9764705882352941, 検証 0.9130434782608695
# 再現率(Recall) : 訓練 0.7217391304347827, 検証 0.5384615384615384
# F1スコア : 訓練 0.83, 検証 0.6774193548387096
# 'rdkit_can.pdf'

# %% [markdown]
# # phi

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 97].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_phi', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_phi'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: phi, Length: 4697, dtype: object
# phi
# False    4581
# True      116
# Name: count, dtype: int64
# 最適な深さ: 43
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.084059
# Na / Si              0.072117
# F / Si               0.122329
# H2O / Si             0.009580
# sda1 / Si            0.036257
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3434     1
# True       3    84
#        False  True
# False   1134    12
# True       2    27
# 正解率(Accuracy) : 訓練 0.9988642816581488, 検証 0.9880851063829788
# 適合率(Precision) : 訓練 0.9882352941176471, 検証 0.6923076923076923
# 再現率(Recall) : 訓練 0.9655172413793104, 検証 0.9310344827586207
# F1スコア : 訓練 0.9767441860465116, 検証 0.7941176470588235
# 'rdkit_phi.pdf'

# %% [markdown]
# # sod

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 98].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_sod', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_sod'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: sod, Length: 4697, dtype: object
# sod
# False    4395
# True      302
# Name: count, dtype: int64
# 最適な深さ: 66
# 最適な最小サンプル数: 4
#                    importance
# Al / Si              0.315559
# Na / Si              0.098574
# F / Si               0.002038
# H2O / Si             0.017172
# sda1 / Si            0.079350
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3271    25
# True      36   190
#        False  True
# False   1079    20
# True      18    58
# 正解率(Accuracy) : 訓練 0.9826802952867689, 検証 0.9676595744680851
# 適合率(Precision) : 訓練 0.8837209302325582, 検証 0.7435897435897436
# 再現率(Recall) : 訓練 0.8407079646017699, 検証 0.7631578947368421
# F1スコア : 訓練 0.8616780045351474, 検証 0.7532467532467533
# 'rdkit_sod.pdf'

# %% [markdown]
# # gme

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 99].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_gme', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_gme'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251       True
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: gme, Length: 4697, dtype: object
# gme
# False    4529
# True      168
# Name: count, dtype: int64
# 最適な深さ: 58
# 最適な最小サンプル数: 2
#                    importance
# Al / Si              0.076341
# Na / Si              0.204212
# F / Si               0.000000
# H2O / Si             0.131075
# sda1 / Si            0.104886
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3393     3
# True      20   106
#        False  True
# False   1124     9
# True       7    35
# 正解率(Accuracy) : 訓練 0.9934696195343555, 検証 0.9863829787234043
# 適合率(Precision) : 訓練 0.9724770642201835, 検証 0.7954545454545454
# 再現率(Recall) : 訓練 0.8412698412698413, 検証 0.8333333333333334
# F1スコア : 訓練 0.902127659574468, 検証 0.813953488372093
# 'rdkit_gme.pdf'

# %% [markdown]
# # pau

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 100].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_pau', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_pau'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: pau, Length: 4697, dtype: object
# pau
# False    4671
# True       26
# Name: count, dtype: int64
# 最適な深さ: 7
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.202900
# Na / Si              0.055086
# F / Si               0.000000
# H2O / Si             0.082629
# sda1 / Si            0.128158
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3503     0
# True       3    16
# C:\Users\yamamoto02\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#        False  True
# False   1168     0
# True       7     0
# 正解率(Accuracy) : 訓練 0.9991482112436116, 検証 0.9940425531914894
# 適合率(Precision) : 訓練 1.0, 検証 0.0
# 再現率(Recall) : 訓練 0.8421052631578947, 検証 0.0
# F1スコア : 訓練 0.9142857142857143, 検証 0.0
# 'rdkit_pau.pdf'

# %% [markdown]
# # lta

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 101].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_lta', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_lta'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: lta, Length: 4697, dtype: object
# lta
# False    4577
# True      120
# Name: count, dtype: int64
# 最適な深さ: 12
# 最適な最小サンプル数: 3
#                    importance
# Al / Si              0.229685
# Na / Si              0.179302
# F / Si               0.000000
# H2O / Si             0.066634
# sda1 / Si            0.019392
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.000000
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3428     4
# True      11    79
#        False  True
# False   1138     7
# True       6    24
# 正解率(Accuracy) : 訓練 0.995741056218058, 検証 0.9889361702127659
# 適合率(Precision) : 訓練 0.9518072289156626, 検証 0.7741935483870968
# 再現率(Recall) : 訓練 0.8777777777777778, 検証 0.8
# F1スコア : 訓練 0.9132947976878613, 検証 0.7868852459016393
# 'rdkit_lta.pdf'

# %% [markdown]
# # jbw

# %%
import pandas as pd
dataset=pd.read_csv('dataset_rdkit_CBU_jbw.csv', index_col=0, header=0)
x=dataset.iloc[:, :76]
y=dataset.iloc[:, 102].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('rdkit_jbw', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='rdkit_jbw'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: jbw, Length: 4697, dtype: object
# jbw
# False    4148
# True      549
# Name: count, dtype: int64
# 最適な深さ: 69
# 最適な最小サンプル数: 1
#                    importance
# Al / Si              0.119420
# Na / Si              0.091647
# F / Si               0.000873
# H2O / Si             0.099971
# sda1 / Si            0.064976
# ...                       ...
# fr_Ndealkylation2    0.000000
# fr_bicyclic          0.003253
# fr_piperdine         0.000000
# fr_quatN             0.000000
# fr_unbrch_alkane     0.000000
#
# [76 rows x 1 columns]
#        False  True
# False   3110     0
# True       6   406
#        False  True
# False   1010    28
# True      20   117
# 正解率(Accuracy) : 訓練 0.9982964224872232, 検証 0.9591489361702128
# 適合率(Precision) : 訓練 1.0, 検証 0.8068965517241379
# 再現率(Recall) : 訓練 0.9854368932038835, 検証 0.8540145985401459
# F1スコア : 訓練 0.9926650366748166, 検証 0.8297872340425532
# 'rdkit_jbw.pdf'
