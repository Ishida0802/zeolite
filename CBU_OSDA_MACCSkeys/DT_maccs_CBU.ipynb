# %% [markdown]
# # mor

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 101].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_mor', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_mor'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951     True
# 29952     True
# 29977     True
# 29978     True
# Name: mor, Length: 4697, dtype: object
# mor
# False    2754
# True     1943
# Name: count, dtype: int64
# 最適な深さ: 13
# 最適な最小サンプル数: 3
#            importance
# Al / Si      0.120101
# Na / Si      0.092380
# F / Si       0.007215
# H2O / Si     0.074504
# sda1 / Si    0.092220
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000418
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   1806   259
# True     242  1215
#        False  True
# False    568   121
# True     146   340
# 正解率(Accuracy) : 訓練 0.8577512776831345, 検証 0.7727659574468085
# 適合率(Precision) : 訓練 0.8242876526458616, 検証 0.737527114967462
# 再現率(Recall) : 訓練 0.8339052848318462, 検証 0.6995884773662552
# F1スコア : 訓練 0.8290685772773797, 検証 0.7180570221752904
# 'maccs_mor.pdf'

# %% [markdown]
# # bea

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 102].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_bea', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_bea'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952     True
# 29977     True
# 29978     True
# Name: bea, Length: 4697, dtype: object
# bea
# False    4232
# True      465
# Name: count, dtype: int64
# 最適な深さ: 10
# 最適な最小サンプル数: 4
#            importance
# Al / Si      0.082804
# Na / Si      0.028086
# F / Si       0.003415
# H2O / Si     0.289779
# sda1 / Si    0.025472
# ...               ...
# MACCS_162    0.022596
# MACCS_163    0.032996
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3129    44
# True     113   236
#        False  True
# False   1014    45
# True      54    62
# 正解率(Accuracy) : 訓練 0.9554230550823396, 検証 0.9157446808510639
# 適合率(Precision) : 訓練 0.8428571428571429, 検証 0.5794392523364486
# 再現率(Recall) : 訓練 0.6762177650429799, 検証 0.5344827586206896
# F1スコア : 訓練 0.7503974562798092, 検証 0.5560538116591929
# 'maccs_bea.pdf'

# %% [markdown]
# # mtt

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 103].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_bea', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_bea'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: mtt, Length: 4697, dtype: object
# mtt
# False    4192
# True      505
# Name: count, dtype: int64
# 最適な深さ: 11
# 最適な最小サンプル数: 3
#            importance
# Al / Si      0.103370
# Na / Si      0.094981
# F / Si       0.002977
# H2O / Si     0.145650
# sda1 / Si    0.045788
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000000
# MACCS_164    0.000000
# MACCS_165    0.073036
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3096    47
# True      92   287
#        False  True
# False   1012    37
# True      47    79
# 正解率(Accuracy) : 訓練 0.9605337876206701, 検証 0.9285106382978724
# 適合率(Precision) : 訓練 0.8592814371257484, 検証 0.6810344827586207
# 再現率(Recall) : 訓練 0.7572559366754618, 検証 0.626984126984127
# F1スコア : 訓練 0.8050490883590463, 検証 0.6528925619834711
# 'maccs_bea.pdf'

# %% [markdown]
# # cas

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 104].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_cas', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_cas'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951     True
# 29952    False
# 29977    False
# 29978    False
# Name: cas, Length: 4697, dtype: object
# cas
# False    3357
# True     1340
# Name: count, dtype: int64
# 最適な深さ: 64
# 最適な最小サンプル数: 6
#            importance
# Al / Si      0.233791
# Na / Si      0.102077
# F / Si       0.015244
# H2O / Si     0.042633
# sda1 / Si    0.071748
# ...               ...
# MACCS_162    0.002599
# MACCS_163    0.003275
# MACCS_164    0.000000
# MACCS_165    0.024959
# MACCS_166    0.000158
#
# [93 rows x 1 columns]
#        False  True
# False   2372   145
# True     248   757
#        False  True
# False    728   112
# True     132   203
# 正解率(Accuracy) : 訓練 0.8884156729131175, 検証 0.7923404255319149
# 適合率(Precision) : 訓練 0.8392461197339246, 検証 0.6444444444444445
# 再現率(Recall) : 訓練 0.7532338308457711, 検証 0.6059701492537314
# F1スコア : 訓練 0.7939171473518616, 検証 0.6246153846153846
# 'maccs_cas.pdf'

# %% [markdown]
# # d6r

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 105].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_d6r', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_d6r'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250       True
# 251      False
# 252      False
# 253       True
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: d6r, Length: 4697, dtype: object
# d6r
# False    3705
# True      992
# Name: count, dtype: int64
# 最適な深さ: 10
# 最適な最小サンプル数: 6
#            importance
# Al / Si      0.059401
# Na / Si      0.076170
# F / Si       0.008483
# H2O / Si     0.067400
# sda1 / Si    0.153280
# ...               ...
# MACCS_162    0.012404
# MACCS_163    0.000000
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   2698    80
# True     253   491
#        False  True
# False    879    48
# True     101   147
# 正解率(Accuracy) : 訓練 0.9054514480408858, 検証 0.8731914893617021
# 適合率(Precision) : 訓練 0.8598949211908932, 検証 0.7538461538461538
# 再現率(Recall) : 訓練 0.6599462365591398, 検証 0.592741935483871
# F1スコア : 訓練 0.7467680608365019, 検証 0.6636568848758465
# 'maccs_d6r.pdf'

# %% [markdown]
# # fer

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 106].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_fer', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_fer'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: fer, Length: 4697, dtype: object
# fer
# False    4455
# True      242
# Name: count, dtype: int64
# 最適な深さ: 53
# 最適な最小サンプル数: 4
#            importance
# Al / Si      0.097599
# Na / Si      0.295852
# F / Si       0.028550
# H2O / Si     0.056370
# sda1 / Si    0.052851
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.003658
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3324    17
# True      76   105
#        False  True
# False   1095    19
# True      33    28
# 正解率(Accuracy) : 訓練 0.9735945485519591, 検証 0.9557446808510638
# 適合率(Precision) : 訓練 0.860655737704918, 検証 0.5957446808510638
# 再現率(Recall) : 訓練 0.580110497237569, 検証 0.45901639344262296
# F1スコア : 訓練 0.693069306930693, 検証 0.5185185185185185
# 'maccs_fer.pdf'

# %% [markdown]
# # mel

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 107].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_mel', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_mel'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951     True
# 29952    False
# 29977    False
# 29978    False
# Name: mel, Length: 4697, dtype: object
# mel
# False    3364
# True     1333
# Name: count, dtype: int64
# 最適な深さ: 10
# 最適な最小サンプル数: 1
#            importance
# Al / Si      0.120876
# Na / Si      0.063428
# F / Si       0.007103
# H2O / Si     0.045377
# sda1 / Si    0.065172
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000000
# MACCS_164    0.000000
# MACCS_165    0.007188
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   2384   138
# True     198   802
#        False  True
# False    738   104
# True     119   214
# 正解率(Accuracy) : 訓練 0.9045996592844975, 検証 0.8102127659574468
# 適合率(Precision) : 訓練 0.8531914893617021, 検証 0.6729559748427673
# 再現率(Recall) : 訓練 0.802, 検証 0.6426426426426426
# F1スコア : 訓練 0.8268041237113402, 検証 0.6574500768049155
# 'maccs_mel.pdf'

# %% [markdown]
# # mfi

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 108].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_mfi', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_mfi'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951     True
# 29952    False
# 29977    False
# 29978    False
# Name: mfi, Length: 4697, dtype: object
# mfi
# False    3502
# True     1195
# Name: count, dtype: int64
# 最適な深さ: 8
# 最適な最小サンプル数: 10
#            importance
# Al / Si      0.153990
# Na / Si      0.031844
# F / Si       0.010455
# H2O / Si     0.021794
# sda1 / Si    0.031682
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000000
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   2452   174
# True     273   623
#        False  True
# False    788    88
# True     115   184
# 正解率(Accuracy) : 訓練 0.873083475298126, 検証 0.8272340425531914
# 適合率(Precision) : 訓練 0.7816813048933501, 検証 0.6764705882352942
# 再現率(Recall) : 訓練 0.6953125, 検証 0.6153846153846154
# F1スコア : 訓練 0.7359716479621973, 検証 0.6444833625218914
# 'maccs_mfi.pdf'

# %% [markdown]
# # mtw

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 109].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_mtw', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_mtw'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952     True
# 29977     True
# 29978     True
# Name: mtw, Length: 4697, dtype: object
# mtw
# False    4050
# True      647
# Name: count, dtype: int64
# 最適な深さ: 9
# 最適な最小サンプル数: 6
#            importance
# Al / Si      0.076332
# Na / Si      0.054938
# F / Si       0.013754
# H2O / Si     0.164059
# sda1 / Si    0.130378
# ...               ...
# MACCS_162    0.008276
# MACCS_163    0.000973
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   2949    88
# True     194   291
#        False  True
# False    972    41
# True      93    69
# 正解率(Accuracy) : 訓練 0.919931856899489, 検証 0.8859574468085106
# 適合率(Precision) : 訓練 0.7678100263852242, 検証 0.6272727272727273
# 再現率(Recall) : 訓練 0.6, 検証 0.42592592592592593
# F1スコア : 訓練 0.6736111111111112, 検証 0.5073529411764706
# 'maccs_mtw.pdf'

# %% [markdown]
# # ton

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 110].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_ton', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_ton'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: ton, Length: 4697, dtype: object
# ton
# False    4306
# True      391
# Name: count, dtype: int64
# 最適な深さ: 21
# 最適な最小サンプル数: 5
#            importance
# Al / Si      0.163719
# Na / Si      0.028566
# F / Si       0.001003
# H2O / Si     0.058149
# sda1 / Si    0.099526
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000000
# MACCS_164    0.000000
# MACCS_165    0.036548
# MACCS_166    0.006165
#
# [93 rows x 1 columns]
#        False  True
# False   3197    32
# True      90   203
#        False  True
# False   1039    38
# True      39    59
# 正解率(Accuracy) : 訓練 0.9653605905735377, 検証 0.934468085106383
# 適合率(Precision) : 訓練 0.8638297872340426, 検証 0.6082474226804123
# 再現率(Recall) : 訓練 0.6928327645051194, 検証 0.6020408163265306
# F1スコア : 訓練 0.7689393939393939, 検証 0.6051282051282051
# 'maccs_ton.pdf'

# %% [markdown]
# # non

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 111].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_non', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_non'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: non, Length: 4697, dtype: object
# non
# False    4579
# True      118
# Name: count, dtype: int64
# 最適な深さ: 21
# 最適な最小サンプル数: 2
#            importance
# Al / Si      0.088267
# Na / Si      0.080019
# F / Si       0.029509
# H2O / Si     0.124885
# sda1 / Si    0.020812
# ...               ...
# MACCS_162    0.007923
# MACCS_163    0.000000
# MACCS_164    0.000000
# MACCS_165    0.031340
# MACCS_166    0.174007
#
# [93 rows x 1 columns]
#        False  True
# False   3427     7
# True      31    57
#        False  True
# False   1133    12
# True      19    11
# 正解率(Accuracy) : 訓練 0.9892106757524134, 検証 0.9736170212765958
# 適合率(Precision) : 訓練 0.890625, 検証 0.4782608695652174
# 再現率(Recall) : 訓練 0.6477272727272727, 検証 0.36666666666666664
# F1スコア : 訓練 0.75, 検証 0.41509433962264153
# 'maccs_non.pdf'

# %% [markdown]
# # d8r

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 112].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_d8r', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_d8r'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: d8r, Length: 4697, dtype: object
# d8r
# False    4671
# True       26
# Name: count, dtype: int64
# 最適な深さ: 3
# 最適な最小サンプル数: 4
#            importance
# Al / Si      0.000000
# Na / Si      0.000000
# F / Si       0.012618
# H2O / Si     0.000000
# sda1 / Si    0.315945
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000000
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3501     2
# True      14     5
#        False  True
# False   1167     1
# True       6     1
# 正解率(Accuracy) : 訓練 0.9954571266325951, 検証 0.9940425531914894
# 適合率(Precision) : 訓練 0.7142857142857143, 検証 0.5
# 再現率(Recall) : 訓練 0.2631578947368421, 検証 0.14285714285714285
# F1スコア : 訓練 0.38461538461538464, 検証 0.2222222222222222
# 'maccs_d8r.pdf'

# %% [markdown]
# # can

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 113].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_can', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_can'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: can, Length: 4697, dtype: object
# can
# False    4543
# True      154
# Name: count, dtype: int64
# 最適な深さ: 12
# 最適な最小サンプル数: 4
#            importance
# Al / Si      0.122862
# Na / Si      0.147623
# F / Si       0.000000
# H2O / Si     0.042783
# sda1 / Si    0.234486
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000000
# MACCS_164    0.074859
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3395    12
# True      37    78
#        False  True
# False   1126    10
# True      22    17
# 正解率(Accuracy) : 訓練 0.9860874503123226, 検証 0.9727659574468085
# 適合率(Precision) : 訓練 0.8666666666666667, 検証 0.6296296296296297
# 再現率(Recall) : 訓練 0.6782608695652174, 検証 0.4358974358974359
# F1スコア : 訓練 0.7609756097560976, 検証 0.5151515151515151
# 'maccs_can.pdf'

# %% [markdown]
# # phi

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 114].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_phi', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_phi'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: phi, Length: 4697, dtype: object
# phi
# False    4581
# True      116
# Name: count, dtype: int64
# 最適な深さ: 8
# 最適な最小サンプル数: 4
#            importance
# Al / Si      0.041425
# Na / Si      0.041908
# F / Si       0.124614
# H2O / Si     0.007958
# sda1 / Si    0.040628
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000000
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3427     8
# True      26    61
#        False  True
# False   1134    12
# True       9    20
# 正解率(Accuracy) : 訓練 0.9903463940942646, 検証 0.9821276595744681
# 適合率(Precision) : 訓練 0.8840579710144928, 検証 0.625
# 再現率(Recall) : 訓練 0.7011494252873564, 検証 0.6896551724137931
# F1スコア : 訓練 0.782051282051282, 検証 0.6557377049180327
# 'maccs_phi.pdf'

# %% [markdown]
# # sod

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 115].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_sod', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_sod'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: sod, Length: 4697, dtype: object
# sod
# False    4395
# True      302
# Name: count, dtype: int64
# 最適な深さ: 16
# 最適な最小サンプル数: 9
#            importance
# Al / Si      0.164608
# Na / Si      0.102656
# F / Si       0.000000
# H2O / Si     0.130865
# sda1 / Si    0.080903
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000310
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3255    41
# True     111   115
#        False  True
# False   1075    24
# True      42    34
# 正解率(Accuracy) : 訓練 0.9568427030096536, 検証 0.9438297872340425
# 適合率(Precision) : 訓練 0.7371794871794872, 検証 0.5862068965517241
# 再現率(Recall) : 訓練 0.5088495575221239, 検証 0.4473684210526316
# F1スコア : 訓練 0.6020942408376964, 検証 0.5074626865671642
# 'maccs_sod.pdf'

# %% [markdown]
# # gme

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 116].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_gme', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_gme'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250       True
# 251      False
# 252      False
# 253       True
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: gme, Length: 4697, dtype: object
# gme
# False    4529
# True      168
# Name: count, dtype: int64
# 最適な深さ: 41
# 最適な最小サンプル数: 5
#            importance
# Al / Si      0.170146
# Na / Si      0.025724
# F / Si       0.000000
# H2O / Si     0.266451
# sda1 / Si    0.102070
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000000
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3381    15
# True      55    71
#        False  True
# False   1121    12
# True      19    23
# 正解率(Accuracy) : 訓練 0.9801249290176036, 検証 0.9736170212765958
# 適合率(Precision) : 訓練 0.8255813953488372, 検証 0.6571428571428571
# 再現率(Recall) : 訓練 0.5634920634920635, 検証 0.5476190476190477
# F1スコア : 訓練 0.6698113207547169, 検証 0.5974025974025974
# 'maccs_gme.pdf'

# %% [markdown]
# # pau

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 117].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_pau', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_pau'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: pau, Length: 4697, dtype: object
# pau
# False    4671
# True       26
# Name: count, dtype: int64
# 最適な深さ: 2
# 最適な最小サンプル数: 2
#            importance
# Al / Si      0.000000
# Na / Si      0.000000
# F / Si       0.000000
# H2O / Si     0.193719
# sda1 / Si    0.000000
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000000
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3501     2
# True      11     8
#        False  True
# False   1166     2
# True       7     0
# 正解率(Accuracy) : 訓練 0.9963089153889836, 検証 0.9923404255319149
# 適合率(Precision) : 訓練 0.8, 検証 0.0
# 再現率(Recall) : 訓練 0.42105263157894735, 検証 0.0
# F1スコア : 訓練 0.5517241379310345, 検証 0.0
# 'maccs_pau.pdf'

# %% [markdown]
# # lta

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 118].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_lta', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_lta'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: lta, Length: 4697, dtype: object
# lta
# False    4577
# True      120
# Name: count, dtype: int64
# 最適な深さ: 39
# 最適な最小サンプル数: 5
#            importance
# Al / Si      0.045334
# Na / Si      0.055892
# F / Si       0.004882
# H2O / Si     0.088620
# sda1 / Si    0.090220
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000000
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3415    17
# True      46    44
#        False  True
# False   1133    12
# True      20    10
# 正解率(Accuracy) : 訓練 0.9821124361158433, 検証 0.9727659574468085
# 適合率(Precision) : 訓練 0.7213114754098361, 検証 0.45454545454545453
# 再現率(Recall) : 訓練 0.4888888888888889, 検証 0.3333333333333333
# F1スコア : 訓練 0.5827814569536424, 検証 0.38461538461538464
# 'maccs_lta.pdf'

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU_jbw.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 119].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
from sklearn.tree import DecisionTreeClassifier
import numpy as np
max_depths=np.arange(1, 71, 1)
all_min_samples_leaf=np.arange(1, 20, 1)
from sklearn.model_selection import StratifiedKFold
fold=StratifiedKFold(n_splits=5, shuffle=True, random_state=99)
from sklearn.model_selection import GridSearchCV
model_for_cross_validation=DecisionTreeClassifier()
gs_cv=GridSearchCV(model_for_cross_validation, {'max_depth':max_depths, 'min_samples_leaf':all_min_samples_leaf}, cv=fold)
gs_cv.fit(x_train, y_train)
optimal_depths=gs_cv.best_params_['max_depth']
optimal_samples=gs_cv.best_params_['min_samples_leaf']
print(f"最適な深さ: {optimal_depths}")
print(f"最適な最小サンプル数: {optimal_samples}")

model = DecisionTreeClassifier(max_depth=optimal_depths, min_samples_leaf=optimal_samples)
model.fit(x_train, y_train)

importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

from sklearn.tree import export_graphviz
from graphviz import Source
with open('maccs_jbw', 'w') as f:
    export_graphviz(model, out_file=f, feature_names=x.columns, class_names=model.classes_)
dot_file_path='maccs_jbw'
決定木=Source.from_file(dot_file_path)
決定木.view()
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: jbw, Length: 4697, dtype: object
# jbw
# False    4148
# True      549
# Name: count, dtype: int64
# 最適な深さ: 45
# 最適な最小サンプル数: 1
#            importance
# Al / Si      0.188675
# Na / Si      0.094643
# F / Si       0.000901
# H2O / Si     0.095355
# sda1 / Si    0.054450
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.002988
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3109     1
# True      10   402
#        False  True
# False   1000    38
# True      29   108
# 正解率(Accuracy) : 訓練 0.9968767745599092, 検証 0.9429787234042554
# 適合率(Precision) : 訓練 0.9975186104218362, 検証 0.7397260273972602
# 再現率(Recall) : 訓練 0.9757281553398058, 検証 0.7883211678832117
# F1スコア : 訓練 0.9865030674846625, 検証 0.7632508833922261
# 'maccs_jbw.pdf'
