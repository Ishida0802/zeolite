# %% [markdown]
# # mor

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 101].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951     True
# 29952     True
# 29977     True
# 29978     True
# Name: mor, Length: 4697, dtype: object
# mor
# False    2754
# True     1943
# Name: count, dtype: int64
#             importance
# Al / Si    2386.490541
# Na / Si    1207.254196
# F / Si      194.466627
# H2O / Si   1622.264580
# sda1 / Si  1609.574841
# ...                ...
# MACCS_162    33.257670
# MACCS_163    34.846020
# MACCS_164     1.571860
# MACCS_165    33.628899
# MACCS_166    10.845800
#
# [93 rows x 1 columns]
#        False  True
# False   1940   125
# True     162  1295
#        False  True
# False    587   102
# True     138   348
# 正解率(Accuracy) : 訓練 0.9185122089721749, 検証 0.7957446808510639
# 適合率(Precision) : 訓練 0.9119718309859155, 検証 0.7733333333333333
# 再現率(Recall) : 訓練 0.8888126286890872, 検証 0.7160493827160493
# F1スコア : 訓練 0.9002433090024331, 検証 0.7435897435897436
#  96%|=================== | 3384/3522 [00:11<00:00]

# %% [markdown]
# # bea

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 102].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952     True
# 29977     True
# 29978     True
# Name: bea, Length: 4697, dtype: object
# bea
# False    4232
# True      465
# Name: count, dtype: int64
#             importance
# Al / Si     972.417866
# Na / Si     682.636703
# F / Si      118.715390
# H2O / Si   2184.235227
# sda1 / Si  1217.158592
# ...                ...
# MACCS_162   251.325009
# MACCS_163    10.622021
# MACCS_164     0.861825
# MACCS_165    21.488902
# MACCS_166     0.823380
#
# [93 rows x 1 columns]
#        False  True
# False   3156    17
# True      14   335
#        False  True
# False   1013    46
# True      59    57
# 正解率(Accuracy) : 訓練 0.9911981828506531, 検証 0.9106382978723404
# 適合率(Precision) : 訓練 0.9517045454545454, 検証 0.5533980582524272
# 再現率(Recall) : 訓練 0.9598853868194842, 検証 0.49137931034482757
# F1スコア : 訓練 0.9557774607703281, 検証 0.5205479452054794
#  92%|==================  | 3228/3522 [00:11<00:01]

# %% [markdown]
# # mtt

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 103].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: mtt, Length: 4697, dtype: object
# mtt
# False    4192
# True      505
# Name: count, dtype: int64
#             importance
# Al / Si    1205.500140
# Na / Si     728.873247
# F / Si       54.571663
# H2O / Si   1976.605199
# sda1 / Si   885.428105
# ...                ...
# MACCS_162     0.000000
# MACCS_163   274.741569
# MACCS_164    18.599040
# MACCS_165   524.313393
# MACCS_166     0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3127    16
# True      30   349
#        False  True
# False   1021    28
# True      43    83
# 正解率(Accuracy) : 訓練 0.986939239068711, 検証 0.9395744680851064
# 適合率(Precision) : 訓練 0.9561643835616438, 検証 0.7477477477477478
# 再現率(Recall) : 訓練 0.920844327176781, 検証 0.6587301587301587
# F1スコア : 訓練 0.9381720430107527, 検証 0.70042194092827
#  93%|=================== | 3280/3522 [00:11<00:00]

# %% [markdown]
# # cas

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 104].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951     True
# 29952    False
# 29977    False
# 29978    False
# Name: cas, Length: 4697, dtype: object
# cas
# False    3357
# True     1340
# Name: count, dtype: int64
#             importance
# Al / Si    3610.117549
# Na / Si    1303.685831
# F / Si      154.050471
# H2O / Si   1188.742218
# sda1 / Si  1034.406849
# ...                ...
# MACCS_162   119.342081
# MACCS_163    70.340669
# MACCS_164     4.545650
# MACCS_165   105.725492
# MACCS_166     0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   2428    89
# True     136   869
#        False  True
# False    750    90
# True     114   221
# 正解率(Accuracy) : 訓練 0.9361158432708688, 検証 0.8263829787234043
# 適合率(Precision) : 訓練 0.907098121085595, 検証 0.7106109324758842
# 再現率(Recall) : 訓練 0.8646766169154229, 検証 0.6597014925373135
# F1スコア : 訓練 0.8853795211411105, 検証 0.6842105263157895
#  98%|===================| 3460/3522 [00:12<00:00]

# %% [markdown]
# # d6r

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 105].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250       True
# 251      False
# 252      False
# 253       True
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: d6r, Length: 4697, dtype: object
# d6r
# False    3705
# True      992
# Name: count, dtype: int64
#             importance
# Al / Si    1723.200953
# Na / Si    1167.791192
# F / Si      130.898760
# H2O / Si   1314.267408
# sda1 / Si  2144.381089
# ...                ...
# MACCS_162    74.786063
# MACCS_163    37.951342
# MACCS_164     4.724610
# MACCS_165    90.652794
# MACCS_166     0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   2729    49
# True     115   629
#        False  True
# False    872    55
# True      89   159
# 正解率(Accuracy) : 訓練 0.9534355479840999, 検証 0.8774468085106383
# 適合率(Precision) : 訓練 0.9277286135693216, 検証 0.7429906542056075
# 再現率(Recall) : 訓練 0.8454301075268817, 検証 0.6411290322580645
# F1スコア : 訓練 0.8846694796061885, 検証 0.6883116883116883
#  97%|=================== | 3411/3522 [00:11<00:00]

# %% [markdown]
# # fer

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 106].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: fer, Length: 4697, dtype: object
# fer
# False    4455
# True      242
# Name: count, dtype: int64
#             importance
# Al / Si     888.256070
# Na / Si    1289.265338
# F / Si       57.143953
# H2O / Si    775.154147
# sda1 / Si   992.011231
# ...                ...
# MACCS_162     1.535990
# MACCS_163    22.742473
# MACCS_164     0.000000
# MACCS_165     2.610700
# MACCS_166     0.491200
#
# [93 rows x 1 columns]
#        False  True
# False   3336     5
# True      20   161
#        False  True
# False   1104    10
# True      33    28
# 正解率(Accuracy) : 訓練 0.9929017603634299, 検証 0.963404255319149
# 適合率(Precision) : 訓練 0.9698795180722891, 検証 0.7368421052631579
# 再現率(Recall) : 訓練 0.8895027624309392, 検証 0.45901639344262296
# F1スコア : 訓練 0.9279538904899135, 検証 0.5656565656565656
#  95%|=================== | 3355/3522 [00:12<00:00]

# %% [markdown]
# # mel

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 107].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951     True
# 29952    False
# 29977    False
# 29978    False
# Name: mel, Length: 4697, dtype: object
# mel
# False    3364
# True     1333
# Name: count, dtype: int64
#             importance
# Al / Si    1944.240350
# Na / Si    1198.825851
# F / Si      144.085658
# H2O / Si   1432.822769
# sda1 / Si  1287.896852
# ...                ...
# MACCS_162    83.898151
# MACCS_163    43.407798
# MACCS_164     4.420070
# MACCS_165    83.747451
# MACCS_166     0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   2436    86
# True     163   837
#        False  True
# False    744    98
# True     108   225
# 正解率(Accuracy) : 訓練 0.9293015332197615, 検証 0.8246808510638298
# 適合率(Precision) : 訓練 0.9068255687973997, 検証 0.6965944272445821
# 再現率(Recall) : 訓練 0.837, 検証 0.6756756756756757
# F1スコア : 訓練 0.8705148205928237, 検証 0.6859756097560976
#  97%|=================== | 3430/3522 [00:11<00:00]

# %% [markdown]
# # mfi

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 108].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950     True
# 29951     True
# 29952    False
# 29977    False
# 29978    False
# Name: mfi, Length: 4697, dtype: object
# mfi
# False    3502
# True     1195
# Name: count, dtype: int64
#             importance
# Al / Si    2616.962270
# Na / Si    1053.110425
# F / Si       90.370761
# H2O / Si   1391.174935
# sda1 / Si  1197.715604
# ...                ...
# MACCS_162   167.049457
# MACCS_163    36.280843
# MACCS_164     0.000000
# MACCS_165    74.674031
# MACCS_166    16.097745
#
# [93 rows x 1 columns]
#        False  True
# False   2563    63
# True     149   747
#        False  True
# False    795    81
# True     121   178
# 正解率(Accuracy) : 訓練 0.9398069278818852, 検証 0.8280851063829787
# 適合率(Precision) : 訓練 0.9222222222222223, 検証 0.6872586872586872
# 再現率(Recall) : 訓練 0.8337053571428571, 検証 0.5953177257525084
# F1スコア : 訓練 0.8757327080890973, 検証 0.6379928315412187

# %% [markdown]
# # mtw

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 109].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952     True
# 29977     True
# 29978     True
# Name: mtw, Length: 4697, dtype: object
# mtw
# False    4050
# True      647
# Name: count, dtype: int64
#             importance
# Al / Si    1116.631321
# Na / Si     987.534191
# F / Si      184.544865
# H2O / Si   2114.974903
# sda1 / Si  1296.659559
# ...                ...
# MACCS_162    27.773385
# MACCS_163    42.751581
# MACCS_164    25.907258
# MACCS_165     8.664436
# MACCS_166     0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3014    23
# True      74   411
#        False  True
# False    977    36
# True      85    77
# 正解率(Accuracy) : 訓練 0.9724588302101079, 検証 0.8970212765957447
# 適合率(Precision) : 訓練 0.9470046082949308, 検証 0.6814159292035398
# 再現率(Recall) : 訓練 0.8474226804123711, 検証 0.47530864197530864
# F1スコア : 訓練 0.8944504896626768, 検証 0.56

# %% [markdown]
# # ton

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 110].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: ton, Length: 4697, dtype: object
# ton
# False    4306
# True      391
# Name: count, dtype: int64
#             importance
# Al / Si    1111.247910
# Na / Si     647.256231
# F / Si       78.250192
# H2O / Si   1177.718903
# sda1 / Si   620.927409
# ...                ...
# MACCS_162     3.433940
# MACCS_163    98.563246
# MACCS_164     8.170277
# MACCS_165   420.432649
# MACCS_166     1.306224
#
# [93 rows x 1 columns]
#        False  True
# False   3223     6
# True      23   270
#        False  True
# False   1047    30
# True      31    67
# 正解率(Accuracy) : 訓練 0.9917660420215787, 検証 0.9480851063829787
# 適合率(Precision) : 訓練 0.9782608695652174, 検証 0.6907216494845361
# 再現率(Recall) : 訓練 0.9215017064846417, 検証 0.6836734693877551
# F1スコア : 訓練 0.9490333919156415, 検証 0.6871794871794872
#  95%|=================== | 3360/3522 [00:12<00:00]

# %% [markdown]
# # non

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 111].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: non, Length: 4697, dtype: object
# non
# False    4579
# True      118
# Name: count, dtype: int64
#            importance
# Al / Si    503.073324
# Na / Si    397.028803
# F / Si     146.316498
# H2O / Si   402.680158
# sda1 / Si  275.029217
# ...               ...
# MACCS_162    2.231306
# MACCS_163   15.715387
# MACCS_164    0.000000
# MACCS_165   17.242034
# MACCS_166  451.536804
#
# [93 rows x 1 columns]
#        False  True
# False   3432     2
# True       9    79
#        False  True
# False   1136     9
# True      17    13
# 正解率(Accuracy) : 訓練 0.9968767745599092, 検証 0.977872340425532
# 適合率(Precision) : 訓練 0.9753086419753086, 検証 0.5909090909090909
# 再現率(Recall) : 訓練 0.8977272727272727, 検証 0.43333333333333335
# F1スコア : 訓練 0.9349112426035503, 検証 0.5
#  93%|=================== | 3260/3522 [00:12<00:00]

# %% [markdown]
# # d8r

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 112].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: d8r, Length: 4697, dtype: object
# d8r
# False    4671
# True       26
# Name: count, dtype: int64
#            importance
# Al / Si    178.660031
# Na / Si     75.044630
# F / Si      35.901178
# H2O / Si   345.130312
# sda1 / Si  113.301282
# ...               ...
# MACCS_162    0.022991
# MACCS_163    0.000000
# MACCS_164    0.316258
# MACCS_165    0.000026
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3503     0
# True       3    16
#        False  True
# False   1165     3
# True       6     1
# 正解率(Accuracy) : 訓練 0.9991482112436116, 検証 0.9923404255319149
# 適合率(Precision) : 訓練 1.0, 検証 0.25
# 再現率(Recall) : 訓練 0.8421052631578947, 検証 0.14285714285714285
# F1スコア : 訓練 0.9142857142857143, 検証 0.18181818181818182

# %% [markdown]
# # can

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 113].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: can, Length: 4697, dtype: object
# can
# False    4543
# True      154
# Name: count, dtype: int64
#             importance
# Al / Si    1003.626846
# Na / Si     503.118797
# F / Si        2.759864
# H2O / Si    480.999516
# sda1 / Si   959.802563
# ...                ...
# MACCS_162     0.032075
# MACCS_163     4.763675
# MACCS_164     0.066221
# MACCS_165    33.723644
# MACCS_166   163.691963
#
# [93 rows x 1 columns]
#        False  True
# False   3406     1
# True      10   105
#        False  True
# False   1127     9
# True      19    20
# 正解率(Accuracy) : 訓練 0.9968767745599092, 検証 0.9761702127659575
# 適合率(Precision) : 訓練 0.9905660377358491, 検証 0.6896551724137931
# 再現率(Recall) : 訓練 0.9130434782608695, 検証 0.5128205128205128
# F1スコア : 訓練 0.9502262443438914, 検証 0.5882352941176471
#  93%|=================== | 3273/3522 [00:11<00:00]

# %% [markdown]
# # phi

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 114].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: phi, Length: 4697, dtype: object
# phi
# False    4581
# True      116
# Name: count, dtype: int64
#            importance
# Al / Si    815.337800
# Na / Si    271.673677
# F / Si     241.077023
# H2O / Si   387.562451
# sda1 / Si  244.583805
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.000000
# MACCS_164    0.000000
# MACCS_165    0.055455
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3430     5
# True       2    85
#        False  True
# False   1135    11
# True       5    24
# 正解率(Accuracy) : 訓練 0.9980124929017604, 検証 0.9863829787234043
# 適合率(Precision) : 訓練 0.9444444444444444, 検証 0.6857142857142857
# 再現率(Recall) : 訓練 0.9770114942528736, 検証 0.8275862068965517
# F1スコア : 訓練 0.96045197740113, 検証 0.75
#  97%|=================== | 3429/3522 [00:11<00:00]

# %% [markdown]
# # sod

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 115].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: sod, Length: 4697, dtype: object
# sod
# False    4395
# True      302
# Name: count, dtype: int64
#             importance
# Al / Si    1061.261618
# Na / Si     665.177700
# F / Si       36.433930
# H2O / Si    889.902269
# sda1 / Si   666.168879
# ...                ...
# MACCS_162     1.369242
# MACCS_163     4.285566
# MACCS_164     2.313702
# MACCS_165    18.946350
# MACCS_166     0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3290     6
# True      22   204
#        False  True
# False   1072    27
# True      42    34
# 正解率(Accuracy) : 訓練 0.9920499716070414, 検証 0.9412765957446808
# 適合率(Precision) : 訓練 0.9714285714285714, 検証 0.5573770491803278
# 再現率(Recall) : 訓練 0.9026548672566371, 検証 0.4473684210526316
# F1スコア : 訓練 0.9357798165137615, 検証 0.49635036496350365
#  99%|===================| 3493/3522 [00:12<00:00]

# %% [markdown]
# # gme

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 116].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250       True
# 251      False
# 252      False
# 253       True
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: gme, Length: 4697, dtype: object
# gme
# False    4529
# True      168
# Name: count, dtype: int64
#            importance
# Al / Si    604.341753
# Na / Si    842.407269
# F / Si       4.242713
# H2O / Si   838.364768
# sda1 / Si  401.550857
# ...               ...
# MACCS_162    0.221832
# MACCS_163    5.868649
# MACCS_164    0.124862
# MACCS_165    2.599543
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3392     4
# True      13   113
#        False  True
# False   1122    11
# True      20    22
# 正解率(Accuracy) : 訓練 0.9951731970471324, 検証 0.9736170212765958
# 適合率(Precision) : 訓練 0.9658119658119658, 検証 0.6666666666666666
# 再現率(Recall) : 訓練 0.8968253968253969, 検証 0.5238095238095238
# F1スコア : 訓練 0.9300411522633745, 検証 0.5866666666666667
#  96%|=================== | 3390/3522 [00:12<00:00]

# %% [markdown]
# # pau

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 117].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: pau, Length: 4697, dtype: object
# pau
# False    4671
# True       26
# Name: count, dtype: int64
#            importance
# Al / Si     83.621684
# Na / Si     56.646632
# F / Si      21.635059
# H2O / Si   427.868129
# sda1 / Si  655.574736
# ...               ...
# MACCS_162    0.000000
# MACCS_163    0.086859
# MACCS_164    0.000000
# MACCS_165    0.000000
# MACCS_166    2.115246
#
# [93 rows x 1 columns]
#        False  True
# False   3503     0
# True       4    15
#        False  True
# False   1163     5
# True       6     1
# 正解率(Accuracy) : 訓練 0.9988642816581488, 検証 0.9906382978723405
# 適合率(Precision) : 訓練 1.0, 検証 0.16666666666666666
# 再現率(Recall) : 訓練 0.7894736842105263, 検証 0.14285714285714285
# F1スコア : 訓練 0.8823529411764706, 検証 0.15384615384615385
#  95%|=================== | 3357/3522 [00:11<00:00]

# %% [markdown]
# # lta

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 118].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: lta, Length: 4697, dtype: object
# lta
# False    4577
# True      120
# Name: count, dtype: int64
#            importance
# Al / Si    562.870248
# Na / Si    383.937084
# F / Si      56.582345
# H2O / Si   422.223470
# sda1 / Si  512.916198
# ...               ...
# MACCS_162    0.803776
# MACCS_163   11.658641
# MACCS_164    1.012400
# MACCS_165    6.471210
# MACCS_166    0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3427     5
# True       4    86
#        False  True
# False   1134    11
# True      23     7
# 正解率(Accuracy) : 訓練 0.9974446337308348, 検証 0.971063829787234
# 適合率(Precision) : 訓練 0.945054945054945, 検証 0.3888888888888889
# 再現率(Recall) : 訓練 0.9555555555555556, 検証 0.23333333333333334
# F1スコア : 訓練 0.9502762430939227, 検証 0.2916666666666667
#  96%|=================== | 3366/3522 [00:12<00:00]

# %% [markdown]
# # jbw

# %%
import pandas as pd
dataset=pd.read_csv('dataset_maccs_CBU_jbw.csv', index_col=0, header=0)
x=dataset.iloc[:, :93]
y=dataset.iloc[:, 119].astype(str)
display(y)
display(y.value_counts())
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=4)
import lightgbm as lgbm
model=lgbm.LGBMClassifier(importance_type = "gain")
model.fit(x_train, y_train)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)
CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))
from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train, estimated_y_train)
precision_train = metrics.precision_score(y_train, estimated_y_train, pos_label="True")
recall_train = metrics.recall_score(y_train, estimated_y_train, pos_label="True")
f1_train = metrics.f1_score(y_train, estimated_y_train, pos_label="True")
display(confusion_matrix_train)
confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test, estimated_y_test)
precision_test = metrics.precision_score(y_test, estimated_y_test, pos_label="True")
recall_test = metrics.recall_score(y_test, estimated_y_test, pos_label="True")
f1_test = metrics.f1_score(y_test, estimated_y_test, pos_label="True")
display(confusion_matrix_test)
print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import shap

# 新しい統一APIを使用（TreeExplainerではなくこちら）
explainer = shap.Explainer(model, x_train)

# 加法性チェックを無効化
shap_values = explainer(x_train, check_additivity=False)

# summary plotの表示（SHAP値と特徴量を渡す）
shap.summary_plot(shap_values.values, x_train)
# Out:
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
#          ...
# 29950    False
# 29951    False
# 29952    False
# 29977    False
# 29978    False
# Name: jbw, Length: 4697, dtype: object
# jbw
# False    4148
# True      549
# Name: count, dtype: int64
#             importance
# Al / Si    2894.337320
# Na / Si     813.073091
# F / Si       31.764283
# H2O / Si   1137.794036
# sda1 / Si   626.343927
# ...                ...
# MACCS_162     3.894419
# MACCS_163    39.026868
# MACCS_164     0.792692
# MACCS_165    68.024855
# MACCS_166     0.000000
#
# [93 rows x 1 columns]
#        False  True
# False   3105     5
# True       6   406
#        False  True
# False   1017    21
# True      28   109
# 正解率(Accuracy) : 訓練 0.9968767745599092, 検証 0.9582978723404255
# 適合率(Precision) : 訓練 0.9878345498783455, 検証 0.8384615384615385
# 再現率(Recall) : 訓練 0.9854368932038835, 検証 0.7956204379562044
# F1スコア : 訓練 0.9866342648845686, 検証 0.8164794007490637
#  99%|===================| 3474/3522 [00:13<00:00]
