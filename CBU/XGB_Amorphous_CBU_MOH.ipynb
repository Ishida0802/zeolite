# %% [markdown]
# # mor

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 9]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.020396
# H2O/SiO2       0.077699
# MOH/SiO2       0.531132
# temperature    0.311832
# time           0.058941
# トレーニングデータ
#        false  mor
# false    353    0
# mor        0   58
# テストデータ
#        false  mor
# false    115    3
# mor        1   18
# 正解率(Accuracy) : 訓練 1.0, 検証 0.9708029197080292
# 適合率(Precision) : 訓練 1.0, 検証 0.8571428571428571
# 再現率(Recall) : 訓練 1.0, 検証 0.9473684210526315
# F1スコア : 訓練 1.0, 検証 0.9

# %% [markdown]
# # jbw

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 10]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.115043
# H2O/SiO2       0.161058
# MOH/SiO2       0.321391
# temperature    0.353082
# time           0.049426
# トレーニングデータ
#        false  jbw
# false    394    0
# jbw        1   16
# テストデータ
#        false  jbw
# false    131    0
# jbw        0    6
# 正解率(Accuracy) : 訓練 0.9975669099756691, 検証 1.0
# 適合率(Precision) : 訓練 1.0, 検証 1.0
# 再現率(Recall) : 訓練 0.9411764705882353, 検証 1.0
# F1スコア : 訓練 0.9696969696969697, 検証 1.0

# %% [markdown]
# # d6r

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 11]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.244609
# H2O/SiO2       0.160714
# MOH/SiO2       0.250826
# temperature    0.170800
# time           0.173051
# トレーニングデータ
#        d6r  false
# d6r    135      1
# false    1    274
# テストデータ
#        d6r  false
# d6r     35     11
# false    7     84
# 正解率(Accuracy) : 訓練 0.9951338199513382, 検証 0.8686131386861314
# 適合率(Precision) : 訓練 0.9963636363636363, 検証 0.8842105263157894
# 再現率(Recall) : 訓練 0.9963636363636363, 検証 0.9230769230769231
# F1スコア : 訓練 0.9963636363636363, 検証 0.9032258064516129

# %% [markdown]
# # d8r

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 12]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.267809
# H2O/SiO2       0.082107
# MOH/SiO2       0.226522
# temperature    0.212878
# time           0.210683
# トレーニングデータ
#        d8r  false
# d8r     45      1
# false    0    365
# テストデータ
#        d8r  false
# d8r     10      5
# false    2    120
# 正解率(Accuracy) : 訓練 0.9975669099756691, 検証 0.948905109489051
# 適合率(Precision) : 訓練 0.9972677595628415, 検証 0.96
# 再現率(Recall) : 訓練 1.0, 検証 0.9836065573770492
# F1スコア : 訓練 0.9986320109439124, 検証 0.97165991902834

# %% [markdown]
# # can

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 13]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.185330
# H2O/SiO2       0.160974
# MOH/SiO2       0.209208
# temperature    0.322841
# time           0.121648
# トレーニングデータ
#        can  false
# can     82      1
# false    0    328
# テストデータ
#        can  false
# can     26      2
# false    3    106
# 正解率(Accuracy) : 訓練 0.9975669099756691, 検証 0.9635036496350365
# 適合率(Precision) : 訓練 0.9969604863221885, 検証 0.9814814814814815
# 再現率(Recall) : 訓練 1.0, 検証 0.9724770642201835
# F1スコア : 訓練 0.9984779299847792, 検証 0.9769585253456221

# %% [markdown]
# # sod

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 14]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.099005
# H2O/SiO2       0.092092
# MOH/SiO2       0.120815
# temperature    0.605144
# time           0.082943
# トレーニングデータ
#        false  sod
# false    298    0
# sod        0  113
# テストデータ
#        false  sod
# false     95    4
# sod        3   35
# 正解率(Accuracy) : 訓練 1.0, 検証 0.948905109489051
# 適合率(Precision) : 訓練 1.0, 検証 0.8974358974358975
# 再現率(Recall) : 訓練 1.0, 検証 0.9210526315789473
# F1スコア : 訓練 1.0, 検証 0.9090909090909091

# %% [markdown]
# # lta

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 15]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.130305
# H2O/SiO2       0.157089
# MOH/SiO2       0.096258
# temperature    0.571962
# time           0.044386
# トレーニングデータ
#        false  lta
# false    351    0
# lta        0   60
# テストデータ
#        false  lta
# false    117    0
# lta        3   17
# 正解率(Accuracy) : 訓練 1.0, 検証 0.9781021897810219
# 適合率(Precision) : 訓練 1.0, 検証 1.0
# 再現率(Recall) : 訓練 1.0, 検証 0.85
# F1スコア : 訓練 1.0, 検証 0.918918918918919

# %% [markdown]
# # 4

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 16]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.168528
# H2O/SiO2       0.122239
# MOH/SiO2       0.394547
# temperature    0.191368
# time           0.123318
# トレーニングデータ
#          4  false
# 4      235      1
# false    2    173
# テストデータ
#         4  false
# 4      74      5
# false   7     51
# 正解率(Accuracy) : 訓練 0.9927007299270073, 検証 0.9124087591240876
# 適合率(Precision) : 訓練 0.9942528735632183, 検証 0.9107142857142857
# 再現率(Recall) : 訓練 0.9885714285714285, 検証 0.8793103448275862
# F1スコア : 訓練 0.9914040114613181, 検証 0.8947368421052632

# %% [markdown]
# # 6

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 17]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.129440
# H2O/SiO2       0.143440
# MOH/SiO2       0.348977
# temperature    0.174011
# time           0.204132
# トレーニングデータ
#          6  false
# 6      229      1
# false    0    181
# テストデータ
#         6  false
# 6      70      6
# false  12     49
# 正解率(Accuracy) : 訓練 0.9975669099756691, 検証 0.8686131386861314
# 適合率(Precision) : 訓練 0.9945054945054945, 検証 0.8909090909090909
# 再現率(Recall) : 訓練 1.0, 検証 0.8032786885245902
# F1スコア : 訓練 0.9972451790633609, 検証 0.8448275862068966

# %% [markdown]
# # 8

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 18]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.267416
# H2O/SiO2       0.135330
# MOH/SiO2       0.202485
# temperature    0.186454
# time           0.208316
# トレーニングデータ
#          8  false
# 8      131      0
# false    0    280
# テストデータ
#         8  false
# 8      33     11
# false   9     84
# 正解率(Accuracy) : 訓練 1.0, 検証 0.8540145985401459
# 適合率(Precision) : 訓練 1.0, 検証 0.8842105263157894
# 再現率(Recall) : 訓練 1.0, 検証 0.9032258064516129
# F1スコア : 訓練 1.0, 検証 0.8936170212765957

# %% [markdown]
# # 5-1

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 19]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.077483
# H2O/SiO2       0.083506
# MOH/SiO2       0.602524
# temperature    0.179444
# time           0.057044
# トレーニングデータ
#        5-1  false
# 5-1     63      0
# false    0    348
# テストデータ
#        5-1  false
# 5-1     21      0
# false    0    116
# 正解率(Accuracy) : 訓練 1.0, 検証 1.0
# 適合率(Precision) : 訓練 1.0, 検証 1.0
# 再現率(Recall) : 訓練 1.0, 検証 1.0
# F1スコア : 訓練 1.0, 検証 1.0

# %% [markdown]
# # 4-2

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 20]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.244609
# H2O/SiO2       0.160714
# MOH/SiO2       0.250826
# temperature    0.170800
# time           0.173051
# トレーニングデータ
#        4-2  false
# 4-2    135      1
# false    1    274
# テストデータ
#        4-2  false
# 4-2     35     11
# false    7     84
# 正解率(Accuracy) : 訓練 0.9951338199513382, 検証 0.8686131386861314
# 適合率(Precision) : 訓練 0.9963636363636363, 検証 0.8842105263157894
# 再現率(Recall) : 訓練 0.9963636363636363, 検証 0.9230769230769231
# F1スコア : 訓練 0.9963636363636363, 検証 0.9032258064516129

# %% [markdown]
# # 6-2

# %%
import pandas as pd
from IPython.display import display
dataset=pd.read_csv('zeolite_CBU_Amorphous.csv', index_col=0, header=0)
x=pd.concat([dataset.iloc[:, 0:2], dataset.iloc[:, 5:8]], axis=1)
y=dataset.iloc[:, 21]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.25, shuffle=True, stratify=y, random_state=3)
import xgboost as xgb
model=xgb.XGBClassifier()
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
y_train_encoded=label_encoder.fit_transform(y_train)
y_test_encoded=label_encoder.fit_transform(y_test)
model.fit(x_train, y_train_encoded)
importance=pd.DataFrame(model.feature_importances_)
importance.index=x.columns
importance.columns=['importance']
display(importance)

CBU=list(set(y))
CBU.sort()
estimated_y_train=pd.DataFrame(model.predict(x_train))
estimated_y_test=pd.DataFrame(model.predict(x_test))

from sklearn import metrics
confusion_matrix_train=pd.DataFrame(metrics.confusion_matrix(y_train_encoded, estimated_y_train), index=CBU, columns=CBU)
accuracy_train=metrics.accuracy_score(y_train_encoded, estimated_y_train)
precision_train = metrics.precision_score(y_train_encoded, estimated_y_train, pos_label=1)
recall_train = metrics.recall_score(y_train_encoded, estimated_y_train, pos_label=1)
f1_train = metrics.f1_score(y_train_encoded, estimated_y_train, pos_label=1)
print(f"トレーニングデータ")
display(confusion_matrix_train)

confusion_matrix_test=pd.DataFrame(metrics.confusion_matrix(y_test_encoded, estimated_y_test), index=CBU, columns=CBU)
accuracy_test=metrics.accuracy_score(y_test_encoded, estimated_y_test)
precision_test = metrics.precision_score(y_test_encoded, estimated_y_test, pos_label=1)
recall_test = metrics.recall_score(y_test_encoded, estimated_y_test, pos_label=1)
f1_test = metrics.f1_score(y_test_encoded, estimated_y_test, pos_label=1)
print(f"テストデータ")
display(confusion_matrix_test)

print(f"正解率(Accuracy) : 訓練 {accuracy_train}, 検証 {accuracy_test}")
print(f"適合率(Precision) : 訓練 {precision_train}, 検証 {precision_test}")
print(f"再現率(Recall) : 訓練 {recall_train}, 検証 {recall_test}")
print(f"F1スコア : 訓練 {f1_train}, 検証 {f1_test}")

import matplotlib.pyplot as plt

import shap
import pandas as pd
x_train = pd.DataFrame(x_train, columns=x.columns)
explainer = shap.Explainer(model, x_train)  
shap_values = explainer(x_train)            
shap.summary_plot(shap_values.values, x_train, plot_size=(8, 6))  
plt.show()

import shap
import pandas as pd
x_test = pd.DataFrame(x_test, columns=x.columns)
explainer = shap.Explainer(model, x_test)  
shap_values = explainer(x_test)            
shap.summary_plot(shap_values.values, x_test, plot_size=(8, 6))
plt.show()
# Out:
#              importance
# Al2O3/SiO2     0.238730
# H2O/SiO2       0.143079
# MOH/SiO2       0.281321
# temperature    0.198736
# time           0.138135
# トレーニングデータ
#        6-2  false
# 6-2    115      0
# false    0    296
# テストデータ
#        6-2  false
# 6-2     32      7
# false   10     88
# 正解率(Accuracy) : 訓練 1.0, 検証 0.8759124087591241
# 適合率(Precision) : 訓練 1.0, 検証 0.9263157894736842
# 再現率(Recall) : 訓練 1.0, 検証 0.8979591836734694
# F1スコア : 訓練 1.0, 検証 0.9119170984455959
